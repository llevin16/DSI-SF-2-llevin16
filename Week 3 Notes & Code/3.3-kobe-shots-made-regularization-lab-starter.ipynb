# %% [markdown]
# # Predicting shots made per game by Kobe Bryant
#
# In this lab you'll be using regularization techniques Ridge, Lasso, and Elastic Net to try and predict well how many shots Kobe Bryant made per game in his career.
#
# ---
#
# ### 1. Load packages and data

# %%
import numpy as np
import pandas as pd
import patsy
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.cross_validation import cross_val_score
from sklearn import metrics

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
kobe = pd.read_csv('kobe_superwide_games.csv')

# %% [markdown]
# ---
#
# ### 2. Examine the data
#
# - How many columns are there?
# - Infer what the observations (rows) and columns represent.
# - Why is this data that regularization might be particularly useful for?

# %%
kobe.head(3)
# Out:
# 0.2244047619048

# %% [markdown]
# ---
#
# ### Make predictor and target variables. Normalize the predictors.
#
# Why is normalization necessary for regularized regressions?
#
# There is a class in sklearn.preprocessing called `StandardScaler`. Look it up and figure out how to use it to normalize your predictor matrix.

# %%
target = kobe[['SHOTS_MADE']]
predictors = kobe.ix[:,1:]

scaler = StandardScaler()
scaled_data = scaler.fit_transform(predictors)

standardized = pd.DataFrame(scaled_data, columns=predictors.columns)
standardized.describe().T
# Out:
#                                                  count          mean  \
# AWAY_GAME                                       1558.0 -7.838545e-18
# SEASON_OPPONENT:atl:1996-97                     1558.0 -1.285352e-15
# SEASON_OPPONENT:atl:1997-98                     1558.0 -1.162216e-15
# SEASON_OPPONENT:atl:1999-00                     1558.0  4.360681e-16
# SEASON_OPPONENT:atl:2000-01                     1558.0  3.266090e-16
# SEASON_OPPONENT:atl:2001-02                     1558.0 -3.869124e-16
# SEASON_OPPONENT:atl:2002-03                     1558.0 -1.132759e-16
# SEASON_OPPONENT:atl:2003-04                     1558.0  4.385577e-17
# SEASON_OPPONENT:atl:2004-05                     1558.0  2.335976e-17
# SEASON_OPPONENT:atl:2005-06                     1558.0  1.193151e-16
# SEASON_OPPONENT:atl:2006-07                     1558.0  2.788919e-17
# SEASON_OPPONENT:atl:2007-08                     1558.0 -1.522281e-17
# SEASON_OPPONENT:atl:2008-09                     1558.0 -2.614956e-16
# SEASON_OPPONENT:atl:2009-10                     1558.0 -3.869124e-16
# SEASON_OPPONENT:atl:2010-11                     1558.0 -7.312383e-16
# SEASON_OPPONENT:atl:2011-12                     1558.0  4.372038e-16
# SEASON_OPPONENT:atl:2012-13                     1558.0 -1.105208e-15
# SEASON_OPPONENT:atl:2013-14                     1558.0  5.147742e-16
# SEASON_OPPONENT:atl:2014-15                     1558.0  5.250355e-16
# SEASON_OPPONENT:atl:2015-16                     1558.0  5.596588e-16
# SEASON_OPPONENT:bkn:2012-13                     1558.0 -9.934732e-16
# SEASON_OPPONENT:bkn:2015-16                     1558.0  5.518202e-16
# SEASON_OPPONENT:bos:1996-97                     1558.0  5.911555e-16
# SEASON_OPPONENT:bos:1997-98                     1558.0 -1.162216e-15
# SEASON_OPPONENT:bos:1999-00                     1558.0 -7.973671e-16
# SEASON_OPPONENT:bos:2001-02                     1558.0 -3.276245e-16
# SEASON_OPPONENT:bos:2002-03                     1558.0 -1.132759e-16
# SEASON_OPPONENT:bos:2003-04                     1558.0  5.090601e-17
# SEASON_OPPONENT:bos:2004-05                     1558.0  1.238757e-16
# SEASON_OPPONENT:bos:2005-06                     1558.0  1.238757e-16
# ...                                                ...           ...
# ACTION_TYPE:pullup_jump_shot                    1558.0  2.793372e-15
# ACTION_TYPE:putback_dunk_shot                   1558.0  6.696344e-16
# ACTION_TYPE:putback_layup_shot                  1558.0  1.110562e-15
# ACTION_TYPE:putback_slam_dunk_shot              1558.0  4.144185e-17
# ACTION_TYPE:reverse_dunk_shot                   1558.0 -7.867405e-16
# ACTION_TYPE:reverse_layup_shot                  1558.0 -1.984506e-15
# ACTION_TYPE:reverse_slam_dunk_shot              1558.0  8.716818e-17
# ACTION_TYPE:running_bank_shot                   1558.0 -6.427963e-16
# ACTION_TYPE:running_dunk_shot                   1558.0 -2.201740e-16
# ACTION_TYPE:running_finger_roll_layup_shot      1558.0  4.229251e-16
# ACTION_TYPE:running_finger_roll_shot            1558.0 -2.464955e-16
# ACTION_TYPE:running_hook_shot                   1558.0 -1.412007e-16
# ACTION_TYPE:running_jump_shot                   1558.0  3.547583e-15
# ACTION_TYPE:running_layup_shot                  1558.0  5.661924e-16
# ACTION_TYPE:running_pull-up_jump_shot           1558.0  4.975071e-16
# ACTION_TYPE:running_reverse_layup_shot          1558.0  8.204106e-16
# ACTION_TYPE:running_slam_dunk_shot              1558.0  5.111934e-16
# ACTION_TYPE:running_tip_shot                    1558.0  2.766739e-16
# ACTION_TYPE:slam_dunk_shot                      1558.0  4.309703e-15
# ACTION_TYPE:step_back_jump_shot                 1558.0 -4.347364e-15
# ACTION_TYPE:tip_layup_shot                      1558.0 -1.301252e-15
# ACTION_TYPE:tip_shot                            1558.0  9.509580e-16
# ACTION_TYPE:turnaround_bank_shot                1558.0  2.031573e-15
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot  1558.0  5.921709e-16
# ACTION_TYPE:turnaround_fadeaway_shot            1558.0  2.402995e-15
# ACTION_TYPE:turnaround_finger_roll_shot         1558.0  1.053037e-16
# ACTION_TYPE:turnaround_hook_shot                1558.0  1.978930e-15
# ACTION_TYPE:turnaround_jump_shot                1558.0 -2.100053e-15
# SEASON_GAME_NUMBER                              1558.0  9.783929e-17
# CAREER_GAME_NUMBER                              1558.0 -2.421398e-16
#
#                                                      std       min       25%  \
# AWAY_GAME                                       1.000321 -1.001285 -1.001285
# SEASON_OPPONENT:atl:1996-97                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:1997-98                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:1999-00                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2000-01                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2001-02                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2002-03                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2003-04                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2004-05                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2005-06                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2006-07                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2007-08                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2008-09                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2009-10                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2010-11                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2011-12                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2012-13                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:atl:2013-14                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2014-15                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:atl:2015-16                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:bkn:2012-13                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bkn:2015-16                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:bos:1996-97                     1.000321 -0.025343 -0.025343
# SEASON_OPPONENT:bos:1997-98                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:1999-00                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:2001-02                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:2002-03                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:2003-04                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:2004-05                     1.000321 -0.035852 -0.035852
# SEASON_OPPONENT:bos:2005-06                     1.000321 -0.035852 -0.035852
# ...                                                  ...       ...       ...
# ACTION_TYPE:pullup_jump_shot                    1.000321 -0.327921 -0.327921
# ACTION_TYPE:putback_dunk_shot                   1.000321 -0.055234 -0.055234
# ACTION_TYPE:putback_layup_shot                  1.000321 -0.097462 -0.097462
# ACTION_TYPE:putback_slam_dunk_shot              1.000321 -0.025343 -0.025343
# ACTION_TYPE:reverse_dunk_shot                   1.000321 -0.210140 -0.210140
# ACTION_TYPE:reverse_layup_shot                  1.000321 -0.447644 -0.447644
# ACTION_TYPE:reverse_slam_dunk_shot              1.000321 -0.096862 -0.096862
# ACTION_TYPE:running_bank_shot                   1.000321 -0.160985 -0.160985
# ACTION_TYPE:running_dunk_shot                   1.000321 -0.108008 -0.108008
# ACTION_TYPE:running_finger_roll_layup_shot      1.000321 -0.061056 -0.061056
# ACTION_TYPE:running_finger_roll_shot            1.000321 -0.049404 -0.049404
# ACTION_TYPE:running_hook_shot                   1.000321 -0.151081 -0.151081
# ACTION_TYPE:running_jump_shot                   1.000321 -0.596082 -0.596082
# ACTION_TYPE:running_layup_shot                  1.000321 -0.187324 -0.187324
# ACTION_TYPE:running_pull-up_jump_shot           1.000321 -0.043114 -0.043114
# ACTION_TYPE:running_reverse_layup_shot          1.000321 -0.062828 -0.062828
# ACTION_TYPE:running_slam_dunk_shot              1.000321 -0.025343 -0.025343
# ACTION_TYPE:running_tip_shot                    1.000321 -0.033860 -0.033860
# ACTION_TYPE:slam_dunk_shot                      1.000321 -0.412134 -0.412134
# ACTION_TYPE:step_back_jump_shot                 1.000321 -0.238950 -0.238950
# ACTION_TYPE:tip_layup_shot                      1.000321 -0.035852 -0.035852
# ACTION_TYPE:tip_shot                            1.000321 -0.281806 -0.281806
# ACTION_TYPE:turnaround_bank_shot                1.000321 -0.183922 -0.183922
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot  1.000321 -0.025343 -0.025343
# ACTION_TYPE:turnaround_fadeaway_shot            1.000321 -0.342591 -0.342591
# ACTION_TYPE:turnaround_finger_roll_shot         1.000321 -0.035746 -0.035746
# ACTION_TYPE:turnaround_hook_shot                1.000321 -0.088428 -0.088428
# ACTION_TYPE:turnaround_jump_shot                1.000321 -0.643218 -0.643218
# SEASON_GAME_NUMBER                              1.000321 -1.610867 -0.842813
# CAREER_GAME_NUMBER                              1.000321 -1.733044 -0.865395
#
#                                                      50%       75%        max
# AWAY_GAME                                       0.998717  0.998717   0.998717
# SEASON_OPPONENT:atl:1996-97                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:1997-98                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:1999-00                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2000-01                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2001-02                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2002-03                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2003-04                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2004-05                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2005-06                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2006-07                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2007-08                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2008-09                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2009-10                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2010-11                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2011-12                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2012-13                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:atl:2013-14                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2014-15                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:atl:2015-16                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:bkn:2012-13                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bkn:2015-16                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:bos:1996-97                    -0.025343 -0.025343  39.458839
# SEASON_OPPONENT:bos:1997-98                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:1999-00                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:2001-02                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:2002-03                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:2003-04                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:2004-05                    -0.035852 -0.035852  27.892651
# SEASON_OPPONENT:bos:2005-06                    -0.035852 -0.035852  27.892651
# ...                                                  ...       ...        ...
# ACTION_TYPE:pullup_jump_shot                   -0.327921 -0.327921  10.289975
# ACTION_TYPE:putback_dunk_shot                  -0.055234 -0.055234  23.984830
# ACTION_TYPE:putback_layup_shot                 -0.097462 -0.097462  13.085125
# ACTION_TYPE:putback_slam_dunk_shot             -0.025343 -0.025343  39.458839
# ACTION_TYPE:reverse_dunk_shot                  -0.210140 -0.210140  10.181424
# ACTION_TYPE:reverse_layup_shot                 -0.447644 -0.447644   8.371796
# ACTION_TYPE:reverse_slam_dunk_shot             -0.096862 -0.096862  16.937627
# ACTION_TYPE:running_bank_shot                  -0.160985 -0.160985  13.475842
# ACTION_TYPE:running_dunk_shot                  -0.108008 -0.108008  14.058299
# ACTION_TYPE:running_finger_roll_layup_shot     -0.061056 -0.061056  22.211827
# ACTION_TYPE:running_finger_roll_shot           -0.049404 -0.049404  25.179207
# ACTION_TYPE:running_hook_shot                  -0.151081 -0.151081  11.813122
# ACTION_TYPE:running_jump_shot                  -0.596082  0.406465   8.928113
# ACTION_TYPE:running_layup_shot                 -0.187324 -0.187324  15.258721
# ACTION_TYPE:running_pull-up_jump_shot          -0.043114 -0.043114  28.464527
# ACTION_TYPE:running_reverse_layup_shot         -0.062828 -0.062828  26.322357
# ACTION_TYPE:running_slam_dunk_shot             -0.025343 -0.025343  39.458839
# ACTION_TYPE:running_tip_shot                   -0.033860 -0.033860  35.517146
# ACTION_TYPE:slam_dunk_shot                     -0.412134 -0.412134   8.632933
# ACTION_TYPE:step_back_jump_shot                -0.238950 -0.238950  10.693827
# ACTION_TYPE:tip_layup_shot                     -0.035852 -0.035852  27.892651
# ACTION_TYPE:tip_shot                           -0.281806 -0.281806  11.068391
# ACTION_TYPE:turnaround_bank_shot               -0.183922 -0.183922  11.796861
# ACTION_TYPE:turnaround_fadeaway_bank_jump_shot -0.025343 -0.025343  39.458839
# ACTION_TYPE:turnaround_fadeaway_shot           -0.342591 -0.342591  12.571042
# ACTION_TYPE:turnaround_finger_roll_shot        -0.035746 -0.035746  29.952398
# ACTION_TYPE:turnaround_hook_shot               -0.088428 -0.088428  22.587117
# ACTION_TYPE:turnaround_jump_shot               -0.643218  0.422497   6.503345
# SEASON_GAME_NUMBER                             -0.036357  0.770100   2.383012
# CAREER_GAME_NUMBER                              0.000030  0.865455   1.730881
#
# [644 rows x 8 columns]

# %% [markdown]
# ---
#
# ### Build a linear regression predicting `SHOTS_MADE` from the rest of the columns.
#
# Cross-validate the $R^2$ of a linear regression model with 10 cross-validation folds.
#
# How does it perform?

# %%
lr = LinearRegression()

x = predictors
y = target

model        =  lr.fit(x, y)
predictions  =  model.predict(x)
score        =  model.score(x, y)

scores = cross_val_score(lr, predictors, y, cv=10)
print "Cross-validated scores:", scores

R_squared = metrics.r2_score(y, predictions)
print "Cross-Predicted R^2:", R_squared
# Out:
# Cross-validated scores: [ -2.28311785e+17  -5.05731427e+17  -7.52128097e+15  -1.64706932e+17
#   -7.73941483e+16  -1.16921069e+17  -1.44702808e+16  -2.75209639e+14
#   -4.67472226e+15  -7.17980707e+14]
# Cross-Predicted R^2: 0.807892771734

# %% [markdown]
# ---
#
# ### Find an optimal value for Ridge regression alpha using RidgeCV
#
# [Go to the documentation and read how RidgeCV works.](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.RidgeCV.html)
#
# Hint: once the RidgeCV is fit, the attribute `.alpha_` contains the best alpha parameter it found through cross-validation.
#
# Recall that Ridge performs best searching alphas through logarithmic space (`np.logspace`).

# %%
ridge = RidgeCV(alphas=np.logspace(0,5,200),fit_intercept=False,cv=10)
ridge.fit(x,y)
ridge.alpha_

opt_ridge = Ridge(alpha=ridge.alpha_,fit_intercept=False)

# %% [markdown]
# ---
#
# ### Cross-validate the Ridge $R^2$ with the optimal alpha.
#
# Is it better than the Linear regression? If so, why would this be?

# %%
ridge_scores = cross_val_score(opt_ridge, predictors, y, cv=10)
print "Cross-validated scores:", ridge_scores
print "Mean: ", np.mean(ridge_scores)
# Out:
# Cross-validated scores: [ 0.64358493  0.5244071   0.51837756  0.60441685  0.53548521  0.56056225
#   0.53480591  0.43739465  0.4710879   0.48528824]
# Mean:  0.531541061003

# %% [markdown]
# ---
#
# ### Find an optimal value for Lasso regression alpha using LassoCV
#
# [Go to the documentation and read how LassoCV works.](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoCV.html) It is very similar to RidgeCV.
#
# Hint: again, once the LassoCV is fit, the attribute `.alpha_` contains the best alpha parameter it found through cross-validation.
#
# Recall that Lasso, unlike Ridge, performs best searching alphas through linear space (`np.linspace`). However, you can actually let the LassoCV decide itself what alphas to use by instead setting the keyword argument `n_alphas=` to however many alphas you want it to search over.

# %%
lasso = RidgeCV(alphas=np.arange(0, 0.15, 0.0025),fit_intercept=False,cv=10)
lasso.fit(x,y)
lasso.alpha_

opt_lasso = Lasso(alpha=lasso.alpha_,fit_intercept=False)

# %% [markdown]
# ---
#
# ### Cross-validate the Lasso $R^2$ with the optimal alpha.
#
# Is it better than the Linear regression? Is it better than Ridge? For each, why would this be?
#
# Depending on which $R^2$ is better between the Ridge and Lasso, what can you infer about the primary issue in the data?

# %%
lasso_scores = cross_val_score(opt_lasso, predictors, y, cv=10)
print "Cross-validated scores:", lasso_scores
print "Mean: ", np.mean(lasso_scores)
# Out:
# Cross-validated scores: [ 0.62523891  0.51542013  0.5161596   0.57138981  0.54782538  0.54797083
#   0.50505654  0.42822027  0.45928     0.48492841]
# Mean:  0.520148988892

# %% [markdown]
# ---
#
# ### Look at the coefficients for variables in the Lasso.
#
# 1. Show the coefficient for variables, ordered from largest to smallest coefficient by absolute value.
# 2. What percent of the variables in the original dataset are "zeroed-out" by the lasso?
# 3. What are the most important predictors for how many shots kobe made in a game?
#
# Note: if you only fit the Lasso within cross_val_score, you will have to refit it outside of that
# function to pull out the coefficients.

# %%
opt_lasso.fit(x,y)
# Out:
# Lasso(alpha=0.14749999999999999, copy_X=True, fit_intercept=False,
#    max_iter=1000, normalize=False, positive=False, precompute=False,
#    random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %% [markdown]
# ---
#
# ### Find an optimal value for Elastic Net regression alpha using ElasticNetCV
#
# [Go to the documentation and read how LassoCV works.](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNetCV.html).
#
# Note here that you will be optimizing both the alpha parameter and the l1_ratio:
#
#     alpha: strength of regularization
#     l1_ratio: amount of ridge vs. lasso (0 = all ridge, 1 = all lasso)
#
# Do not include 0 in the search for l1_ratio: it will not allow it and break!
#
# You can use n_alphas for the alpha parameters instead of setting your own values: highly recommended!
#
# Also - be careful setting too many l1_ratios over cross-validation folds in your search. It can take a very long time if you choose too many combinations and for the most part there are diminishing returns in this data.

# %%
elastic = ElasticNetCV(l1_ratio=np.arange(.01,1,.05),n_alphas=50,cv=10)
elastic.fit(x,y)
# Out:
# /home/llevin/anaconda2/envs/dsi/lib/python2.7/site-packages/sklearn/linear_model/coordinate_descent.py:1051: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
opt_elastic = ElasticNet(alpha=elastic.alpha_,l1_ratio=elastic.l1_ratio_)

# %% [markdown]
# ---
#
# ### Cross-validate the ElasticNet $R^2$ with the optimal alpha and l1_ratio.
#
# How does it compare to the other regularized regressions?

# %%
elastic_scores = cross_val_score(opt_elastic, predictors, y, cv=10)
print "Cross-validated scores:", elastic_scores
print "Mean: ", np.mean(elastic_scores)
# Out:
# Cross-validated scores: [ 0.53797685  0.48044185  0.47560029  0.54125653  0.53455716  0.50328487
#   0.4627109   0.39023747  0.42987488  0.43500476]
# Mean:  0.479094555653

# %% [markdown]
# ---
#
# ### Plot the residuals for the ridge, lasso, and elastic net on histograms
#
# This is another way to look at the performance of your model.
#
# The tighter the distribution of residuals around zero, the better your model has performed!
