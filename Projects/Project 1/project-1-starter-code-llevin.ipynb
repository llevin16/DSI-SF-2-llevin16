# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
my_player = {"player_id":16, "player_name":"Lenny", "time_played":576.4, "player_pokemon":{}, "gyms_visited":[]}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']
gyms = ["reddit.com","amazon.com","twitter.com","linkedin.com","ebay.com","netflix.com","amazon.com","stackoverflow.com",
       "github.com","quora.com"]
my_player["gyms_visited"].append(gyms[1])
my_player["gyms_visited"].append(gyms[2])
print my_player["gyms_visited"]
# Out:
# ['amazon.com', 'amazon.com', 'twitter.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!
pokemon = {
    1: {
        "name":"charmander","type":"fire","hp":20,"attack":20,"defense":20,"special_attack":20,"special_defense":20,
        "speed":20
    },
    2: {
        "name":"squirtle","type":"water","hp":15,"attack":15,"defense":15,"special_attack":15,"special_defense":15,
        "speed":15
    },
    3: {
        "name":"bulbasaur","type":"poison","hp":10,"attack":10,"defense":10,"special_attack":10,"special_defense":10,
        "speed":10
    }
}

print pokemon
# Out:
# {1: {'attack': 20, 'defense': 20, 'name': 'charmander', 'special_attack': 20, 'speed': 20, 'hp': 20, 'type': 'fire', 'special_defense': 20}, 2: {'attack': 15, 'defense': 15, 'name': 'squirtle', 'special_attack': 15, 'speed': 15, 'hp': 15, 'type': 'water', 'special_defense': 15}, 3: {'attack': 10, 'defense': 10, 'name': 'bulbasaur', 'special_attack': 10, 'speed': 10, 'hp': 10, 'type': 'poison', 'special_defense': 10}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}
players_dict = {}
players_dict[my_player["player_id"]] = my_player
print players_dict
# Out:
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {}}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'distance_travelled'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# No example output. 
new_player = {"player_id":2,"player_name":"Homie","time_played":15.,"gyms_visited":[],"player_pokemon":{}}
new_player["gyms_visited"].append("quora.com")
new_player["gyms_visited"].append("ebay.com")
players_dict[new_player["player_id"]] = new_player
print new_player
print players_dict
# Out:
# {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {}}
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {2: 9}}, 2: {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has, and what level those pokemon are.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the level of the pokemon.
#
# Give player 1 a level 9 squirtle. Give player 2 a level 4 charmander and a level 6 bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: 9},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: 4, 3: 6},
#      'time_played': 10.0}}
players_dict[16]["player_pokemon"]={2:9}
players_dict[2]["player_pokemon"]={1:4,3:6}
print players_dict
# Out:
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {2: 9}}, 2: {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {1: 4, 3: 6}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.
for gym in gyms:
    for player in players_dict:
        if gym in players_dict[player]["gyms_visited"]:
            print "%s has visited %s" %(players_dict[player]["player_name"],gym)
# Out:
# Lenny has visited amazon.com
# Lenny has visited twitter.com
# Homie has visited ebay.com
# Lenny has visited amazon.com
# Homie has visited quora.com

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the attack and defense values of all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the attack and defense values for all of their pokemon.
# 5. Return the player's power value.
#
# Remember, the attack and defense of a pokemon in the `pokedex` dictionary are lists ordered by level, so you will need to pull out the attack and defense value indexed by the pokemon's level!
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119
def power (player_dict,pokedex,player_id):
    pokemon_list = player_dict[player_id]["player_pokemon"]
    power = 0
    for pokemon in pokedex:
        if pokemon in pokemon_list.keys():
            power += pokedex[pokemon]["attack"] + pokedex[pokemon]["defense"] + pokedex[pokemon]["special_attack"] \
            + pokedex[pokemon]["special_defense"]
    print "%s's power is %s" %(player_dict[player_id]["player_name"],str(power))
    return power

print power(players_dict,pokemon,16)
print power(players_dict,pokemon,2)
# Out:
# Lenny's power is 60
# 60
# Homie's power is 120
# 120

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
output_dex = []
for item in raw_pd.split("\n"):
    item = item.replace('"',"")
    new_line = []
    for line in item.split(","):
        try:
            line = float(line)
        except:
            if line == "":
                line = -1
        new_line.append(line)
    output_dex.append(new_line)

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
def try_catch(x):
    try: 
        return float(x)
    except:
        if x == "":
            return -1
        else:
            return x
    
lc_dex = [[try_catch(line.replace('"',"")) for line in item.split(",")] for item in raw_pd.split("\n")]
lc_dex[:2]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}
def gen_pokedex(pokedex):
    output = {}
    header = pokedex[0]
    data = pokedex[1:]
    for row in data[:-1]:
        pokemon_dict = {}
        for index, item in enumerate(header):
            pokemon_dict[item] = row[index]
        output[row[0]] = pokemon_dict
        print output[row[0]]
    return output

        
#gen_pokedex(lc_dex)

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(pokedex_data, filter_options):
    data = gen_pokedex(pokedex_data)
    output =[]
    for key in filter_options.keys():
        for value in filter_options.values:
            for pokemon in data:
                if type(value) == "Float":
                    if pokemon[key] >= value:
                        output.append(pokemon)
                elif type(value) == "String":
                    if pokemon[key] == value:
                        output.append(pokemon)
    return output

# %%
filter_options = {
    'Attack':   25,
    'Defense':  30,
    'Type':     'Electric'
}

filtered_pokedex(lc_dex,filter_options)
# Out:
# {'Name': 'Bulbasaur', 'SpecialAttack': 65.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 49.0, 'Defense': 49.0, 'PokedexNumber': 1.0, 'SpecialDefense': 65.0, 'Total': 318.0, 'Type': 'GrassPoison'}
# {'Name': 'Ivysaur', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 63.0, 'PokedexNumber': 2.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'GrassPoison'}
# {'Name': 'Venusaur', 'SpecialAttack': 100.0, 'HP': 80.0, 'Speed': 80.0, 'Attack': 82.0, 'Defense': 83.0, 'PokedexNumber': 3.0, 'SpecialDefense': 100.0, 'Total': 525.0, 'Type': 'GrassPoison'}
# {'Name': 'VenusaurMega Venusaur', 'SpecialAttack': 122.0, 'HP': 80.0, 'Speed': 80.0, 'Attack': 100.0, 'Defense': 123.0, 'PokedexNumber': 3.0, 'SpecialDefense': 120.0, 'Total': 625.0, 'Type': 'GrassPoison'}
# {'Name': 'Charmander', 'SpecialAttack': 60.0, 'HP': 39.0, 'Speed': 65.0, 'Attack': 52.0, 'Defense': 43.0, 'PokedexNumber': 4.0, 'SpecialDefense': 50.0, 'Total': 309.0, 'Type': 'Fire'}
# {'Name': 'Charmeleon', 'SpecialAttack': 80.0, 'HP': 58.0, 'Speed': 80.0, 'Attack': 64.0, 'Defense': 58.0, 'PokedexNumber': 5.0, 'SpecialDefense': 65.0, 'Total': 405.0, 'Type': 'Fire'}
# {'Name': 'Charizard', 'SpecialAttack': 109.0, 'HP': 78.0, 'Speed': 100.0, 'Attack': 84.0, 'Defense': 78.0, 'PokedexNumber': 6.0, 'SpecialDefense': 85.0, 'Total': 534.0, 'Type': 'FireFlying'}
# {'Name': 'CharizardMega Charizard X', 'SpecialAttack': 130.0, 'HP': 78.0, 'Speed': 100.0, 'Attack': 130.0, 'Defense': 111.0, 'PokedexNumber': 6.0, 'SpecialDefense': 85.0, 'Total': 634.0, 'Type': 'FireDragon'}
# {'Name': 'CharizardMega Charizard Y', 'SpecialAttack': 159.0, 'HP': 78.0, 'Speed': 100.0, 'Attack': 104.0, 'Defense': 78.0, 'PokedexNumber': 6.0, 'SpecialDefense': 115.0, 'Total': 634.0, 'Type': 'FireFlying'}
# {'Name': 'Squirtle', 'SpecialAttack': 50.0, 'HP': 44.0, 'Speed': 43.0, 'Attack': 48.0, 'Defense': 65.0, 'PokedexNumber': 7.0, 'SpecialDefense': 64.0, 'Total': 314.0, 'Type': 'Water'}
# {'Name': 'Wartortle', 'SpecialAttack': 65.0, 'HP': 59.0, 'Speed': 58.0, 'Attack': 63.0, 'Defense': 80.0, 'PokedexNumber': 8.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'Water'}
# {'Name': 'Blastoise', 'SpecialAttack': 85.0, 'HP': 79.0, 'Speed': 78.0, 'Attack': 83.0, 'Defense': 100.0, 'PokedexNumber': 9.0, 'SpecialDefense': 105.0, 'Total': 530.0, 'Type': 'Water'}
# {'Name': 'BlastoiseMega Blastoise', 'SpecialAttack': 135.0, 'HP': 79.0, 'Speed': 78.0, 'Attack': 103.0, 'Defense': 120.0, 'PokedexNumber': 9.0, 'SpecialDefense': 115.0, 'Total': 630.0, 'Type': 'Water'}
# {'Name': 'Caterpie', 'SpecialAttack': 20.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 30.0, 'Defense': 35.0, 'PokedexNumber': 10.0, 'SpecialDefense': 20.0, 'Total': 195.0, 'Type': 'Bug'}
# {'Name': 'Metapod', 'SpecialAttack': 25.0, 'HP': 50.0, 'Speed': 30.0, 'Attack': 20.0, 'Defense': 55.0, 'PokedexNumber': 11.0, 'SpecialDefense': 25.0, 'Total': 205.0, 'Type': 'Bug'}
# {'Name': 'Butterfree', 'SpecialAttack': 90.0, 'HP': 60.0, 'Speed': 70.0, 'Attack': 45.0, 'Defense': 50.0, 'PokedexNumber': 12.0, 'SpecialDefense': 80.0, 'Total': 395.0, 'Type': 'BugFlying'}
# {'Name': 'Weedle', 'SpecialAttack': 20.0, 'HP': 40.0, 'Speed': 50.0, 'Attack': 35.0, 'Defense': 30.0, 'PokedexNumber': 13.0, 'SpecialDefense': 20.0, 'Total': 195.0, 'Type': 'BugPoison'}
# {'Name': 'Kakuna', 'SpecialAttack': 25.0, 'HP': 45.0, 'Speed': 35.0, 'Attack': 25.0, 'Defense': 50.0, 'PokedexNumber': 14.0, 'SpecialDefense': 25.0, 'Total': 205.0, 'Type': 'BugPoison'}
# {'Name': 'Beedrill', 'SpecialAttack': 45.0, 'HP': 65.0, 'Speed': 75.0, 'Attack': 90.0, 'Defense': 40.0, 'PokedexNumber': 15.0, 'SpecialDefense': 80.0, 'Total': 395.0, 'Type': 'BugPoison'}
# {'Name': 'BeedrillMega Beedrill', 'SpecialAttack': 15.0, 'HP': 65.0, 'Speed': 145.0, 'Attack': 150.0, 'Defense': 40.0, 'PokedexNumber': 15.0, 'SpecialDefense': 80.0, 'Total': 495.0, 'Type': 'BugPoison'}
# {'Name': 'Pidgey', 'SpecialAttack': 35.0, 'HP': 40.0, 'Speed': 56.0, 'Attack': 45.0, 'Defense': 40.0, 'PokedexNumber': 16.0, 'SpecialDefense': 35.0, 'Total': 251.0, 'Type': 'NormalFlying'}
# {'Name': 'Pidgeotto', 'SpecialAttack': 50.0, 'HP': 63.0, 'Speed': 71.0, 'Attack': 60.0, 'Defense': 55.0, 'PokedexNumber': 17.0, 'SpecialDefense': 50.0, 'Total': 349.0, 'Type': 'NormalFlying'}
# {'Name': 'Pidgeot', 'SpecialAttack': 70.0, 'HP': 83.0, 'Speed': 101.0, 'Attack': 80.0, 'Defense': 75.0, 'PokedexNumber': 18.0, 'SpecialDefense': 70.0, 'Total': 479.0, 'Type': 'NormalFlying'}
# {'Name': 'PidgeotMega Pidgeot', 'SpecialAttack': 135.0, 'HP': 83.0, 'Speed': 121.0, 'Attack': 80.0, 'Defense': 80.0, 'PokedexNumber': 18.0, 'SpecialDefense': 80.0, 'Total': 579.0, 'Type': 'NormalFlying'}
# {'Name': 'Rattata', 'SpecialAttack': 25.0, 'HP': 30.0, 'Speed': 72.0, 'Attack': 56.0, 'Defense': 35.0, 'PokedexNumber': 19.0, 'SpecialDefense': 35.0, 'Total': 253.0, 'Type': 'Normal'}
# {'Name': 'Raticate', 'SpecialAttack': 50.0, 'HP': 55.0, 'Speed': 97.0, 'Attack': 81.0, 'Defense': 60.0, 'PokedexNumber': 20.0, 'SpecialDefense': 70.0, 'Total': 413.0, 'Type': 'Normal'}
# {'Name': 'Spearow', 'SpecialAttack': 31.0, 'HP': 40.0, 'Speed': 70.0, 'Attack': 60.0, 'Defense': 30.0, 'PokedexNumber': 21.0, 'SpecialDefense': 31.0, 'Total': 262.0, 'Type': 'NormalFlying'}
# {'Name': 'Fearow', 'SpecialAttack': 61.0, 'HP': 65.0, 'Speed': 100.0, 'Attack': 90.0, 'Defense': 65.0, 'PokedexNumber': 22.0, 'SpecialDefense': 61.0, 'Total': 442.0, 'Type': 'NormalFlying'}
# {'Name': 'Ekans', 'SpecialAttack': 40.0, 'HP': 35.0, 'Speed': 55.0, 'Attack': 60.0, 'Defense': 44.0, 'PokedexNumber': 23.0, 'SpecialDefense': 54.0, 'Total': 288.0, 'Type': 'Poison'}
# {'Name': 'Arbok', 'SpecialAttack': 65.0, 'HP': 60.0, 'Speed': 80.0, 'Attack': 85.0, 'Defense': 69.0, 'PokedexNumber': 24.0, 'SpecialDefense': 79.0, 'Total': 438.0, 'Type': 'Poison'}
# {'Name': 'Pikachu', 'SpecialAttack': 50.0, 'HP': 35.0, 'Speed': 90.0, 'Attack': 55.0, 'Defense': 40.0, 'PokedexNumber': 25.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Electric'}
# {'Name': 'Raichu', 'SpecialAttack': 90.0, 'HP': 60.0, 'Speed': 110.0, 'Attack': 90.0, 'Defense': 55.0, 'PokedexNumber': 26.0, 'SpecialDefense': 80.0, 'Total': 485.0, 'Type': 'Electric'}
# {'Name': 'Sandshrew', 'SpecialAttack': 20.0, 'HP': 50.0, 'Speed': 40.0, 'Attack': 75.0, 'Defense': 85.0, 'PokedexNumber': 27.0, 'SpecialDefense': 30.0, 'Total': 300.0, 'Type': 'Ground'}
# {'Name': 'Sandslash', 'SpecialAttack': 45.0, 'HP': 75.0, 'Speed': 65.0, 'Attack': 100.0, 'Defense': 110.0, 'PokedexNumber': 28.0, 'SpecialDefense': 55.0, 'Total': 450.0, 'Type': 'Ground'}
# {'Name': 'Nidoran\xe2\x99\x80', 'SpecialAttack': 40.0, 'HP': 55.0, 'Speed': 41.0, 'Attack': 47.0, 'Defense': 52.0, 'PokedexNumber': 29.0, 'SpecialDefense': 40.0, 'Total': 275.0, 'Type': 'Poison'}
# {'Name': 'Nidorina', 'SpecialAttack': 55.0, 'HP': 70.0, 'Speed': 56.0, 'Attack': 62.0, 'Defense': 67.0, 'PokedexNumber': 30.0, 'SpecialDefense': 55.0, 'Total': 365.0, 'Type': 'Poison'}
# {'Name': 'Nidoqueen', 'SpecialAttack': 75.0, 'HP': 90.0, 'Speed': 76.0, 'Attack': 92.0, 'Defense': 87.0, 'PokedexNumber': 31.0, 'SpecialDefense': 85.0, 'Total': 505.0, 'Type': 'PoisonGround'}
# {'Name': 'Nidoran\xe2\x99\x82', 'SpecialAttack': 40.0, 'HP': 46.0, 'Speed': 50.0, 'Attack': 57.0, 'Defense': 40.0, 'PokedexNumber': 32.0, 'SpecialDefense': 40.0, 'Total': 273.0, 'Type': 'Poison'}
# {'Name': 'Nidorino', 'SpecialAttack': 55.0, 'HP': 61.0, 'Speed': 65.0, 'Attack': 72.0, 'Defense': 57.0, 'PokedexNumber': 33.0, 'SpecialDefense': 55.0, 'Total': 365.0, 'Type': 'Poison'}
# {'Name': 'Nidoking', 'SpecialAttack': 85.0, 'HP': 81.0, 'Speed': 85.0, 'Attack': 102.0, 'Defense': 77.0, 'PokedexNumber': 34.0, 'SpecialDefense': 75.0, 'Total': 505.0, 'Type': 'PoisonGround'}
# {'Name': 'Clefairy', 'SpecialAttack': 60.0, 'HP': 70.0, 'Speed': 35.0, 'Attack': 45.0, 'Defense': 48.0, 'PokedexNumber': 35.0, 'SpecialDefense': 65.0, 'Total': 323.0, 'Type': 'Fairy'}
# {'Name': 'Clefable', 'SpecialAttack': 95.0, 'HP': 95.0, 'Speed': 60.0, 'Attack': 70.0, 'Defense': 73.0, 'PokedexNumber': 36.0, 'SpecialDefense': 90.0, 'Total': 483.0, 'Type': 'Fairy'}
# {'Name': 'Vulpix', 'SpecialAttack': 50.0, 'HP': 38.0, 'Speed': 65.0, 'Attack': 41.0, 'Defense': 40.0, 'PokedexNumber': 37.0, 'SpecialDefense': 65.0, 'Total': 299.0, 'Type': 'Fire'}
# {'Name': 'Ninetales', 'SpecialAttack': 81.0, 'HP': 73.0, 'Speed': 100.0, 'Attack': 76.0, 'Defense': 75.0, 'PokedexNumber': 38.0, 'SpecialDefense': 100.0, 'Total': 505.0, 'Type': 'Fire'}
# {'Name': 'Jigglypuff', 'SpecialAttack': 45.0, 'HP': 115.0, 'Speed': 20.0, 'Attack': 45.0, 'Defense': 20.0, 'PokedexNumber': 39.0, 'SpecialDefense': 25.0, 'Total': 270.0, 'Type': 'NormalFairy'}
# {'Name': 'Wigglytuff', 'SpecialAttack': 85.0, 'HP': 140.0, 'Speed': 45.0, 'Attack': 70.0, 'Defense': 45.0, 'PokedexNumber': 40.0, 'SpecialDefense': 50.0, 'Total': 435.0, 'Type': 'NormalFairy'}
# {'Name': 'Zubat', 'SpecialAttack': 30.0, 'HP': 40.0, 'Speed': 55.0, 'Attack': 45.0, 'Defense': 35.0, 'PokedexNumber': 41.0, 'SpecialDefense': 40.0, 'Total': 245.0, 'Type': 'PoisonFlying'}
# {'Name': 'Golbat', 'SpecialAttack': 65.0, 'HP': 75.0, 'Speed': 90.0, 'Attack': 80.0, 'Defense': 70.0, 'PokedexNumber': 42.0, 'SpecialDefense': 75.0, 'Total': 455.0, 'Type': 'PoisonFlying'}
# {'Name': 'Oddish', 'SpecialAttack': 75.0, 'HP': 45.0, 'Speed': 30.0, 'Attack': 50.0, 'Defense': 55.0, 'PokedexNumber': 43.0, 'SpecialDefense': 65.0, 'Total': 320.0, 'Type': 'GrassPoison'}
# {'Name': 'Gloom', 'SpecialAttack': 85.0, 'HP': 60.0, 'Speed': 40.0, 'Attack': 65.0, 'Defense': 70.0, 'PokedexNumber': 44.0, 'SpecialDefense': 75.0, 'Total': 395.0, 'Type': 'GrassPoison'}
# {'Name': 'Vileplume', 'SpecialAttack': 110.0, 'HP': 75.0, 'Speed': 50.0, 'Attack': 80.0, 'Defense': 85.0, 'PokedexNumber': 45.0, 'SpecialDefense': 90.0, 'Total': 490.0, 'Type': 'GrassPoison'}
# {'Name': 'Paras', 'SpecialAttack': 45.0, 'HP': 35.0, 'Speed': 25.0, 'Attack': 70.0, 'Defense': 55.0, 'PokedexNumber': 46.0, 'SpecialDefense': 55.0, 'Total': 285.0, 'Type': 'BugGrass'}
# {'Name': 'Parasect', 'SpecialAttack': 60.0, 'HP': 60.0, 'Speed': 30.0, 'Attack': 95.0, 'Defense': 80.0, 'PokedexNumber': 47.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'BugGrass'}
# {'Name': 'Venonat', 'SpecialAttack': 40.0, 'HP': 60.0, 'Speed': 45.0, 'Attack': 55.0, 'Defense': 50.0, 'PokedexNumber': 48.0, 'SpecialDefense': 55.0, 'Total': 305.0, 'Type': 'BugPoison'}
# {'Name': 'Venomoth', 'SpecialAttack': 90.0, 'HP': 70.0, 'Speed': 90.0, 'Attack': 65.0, 'Defense': 60.0, 'PokedexNumber': 49.0, 'SpecialDefense': 75.0, 'Total': 450.0, 'Type': 'BugPoison'}
# {'Name': 'Diglett', 'SpecialAttack': 35.0, 'HP': 10.0, 'Speed': 95.0, 'Attack': 55.0, 'Defense': 25.0, 'PokedexNumber': 50.0, 'SpecialDefense': 45.0, 'Total': 265.0, 'Type': 'Ground'}
# {'Name': 'Dugtrio', 'SpecialAttack': 50.0, 'HP': 35.0, 'Speed': 120.0, 'Attack': 80.0, 'Defense': 50.0, 'PokedexNumber': 51.0, 'SpecialDefense': 70.0, 'Total': 405.0, 'Type': 'Ground'}
# {'Name': 'Meowth', 'SpecialAttack': 40.0, 'HP': 40.0, 'Speed': 90.0, 'Attack': 45.0, 'Defense': 35.0, 'PokedexNumber': 52.0, 'SpecialDefense': 40.0, 'Total': 290.0, 'Type': 'Normal'}
# {'Name': 'Persian', 'SpecialAttack': 65.0, 'HP': 65.0, 'Speed': 115.0, 'Attack': 70.0, 'Defense': 60.0, 'PokedexNumber': 53.0, 'SpecialDefense': 65.0, 'Total': 440.0, 'Type': 'Normal'}
# {'Name': 'Psyduck', 'SpecialAttack': 65.0, 'HP': 50.0, 'Speed': 55.0, 'Attack': 52.0, 'Defense': 48.0, 'PokedexNumber': 54.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Water'}
# {'Name': 'Golduck', 'SpecialAttack': 95.0, 'HP': 80.0, 'Speed': 85.0, 'Attack': 82.0, 'Defense': 78.0, 'PokedexNumber': 55.0, 'SpecialDefense': 80.0, 'Total': 500.0, 'Type': 'Water'}
# {'Name': 'Mankey', 'SpecialAttack': 35.0, 'HP': 40.0, 'Speed': 70.0, 'Attack': 80.0, 'Defense': 35.0, 'PokedexNumber': 56.0, 'SpecialDefense': 45.0, 'Total': 305.0, 'Type': 'Fighting'}
# {'Name': 'Primeape', 'SpecialAttack': 60.0, 'HP': 65.0, 'Speed': 95.0, 'Attack': 105.0, 'Defense': 60.0, 'PokedexNumber': 57.0, 'SpecialDefense': 70.0, 'Total': 455.0, 'Type': 'Fighting'}
# {'Name': 'Growlithe', 'SpecialAttack': 70.0, 'HP': 55.0, 'Speed': 60.0, 'Attack': 70.0, 'Defense': 45.0, 'PokedexNumber': 58.0, 'SpecialDefense': 50.0, 'Total': 350.0, 'Type': 'Fire'}
# {'Name': 'Arcanine', 'SpecialAttack': 100.0, 'HP': 90.0, 'Speed': 95.0, 'Attack': 110.0, 'Defense': 80.0, 'PokedexNumber': 59.0, 'SpecialDefense': 80.0, 'Total': 555.0, 'Type': 'Fire'}
# {'Name': 'Poliwag', 'SpecialAttack': 40.0, 'HP': 40.0, 'Speed': 90.0, 'Attack': 50.0, 'Defense': 40.0, 'PokedexNumber': 60.0, 'SpecialDefense': 40.0, 'Total': 300.0, 'Type': 'Water'}
# {'Name': 'Poliwhirl', 'SpecialAttack': 50.0, 'HP': 65.0, 'Speed': 90.0, 'Attack': 65.0, 'Defense': 65.0, 'PokedexNumber': 61.0, 'SpecialDefense': 50.0, 'Total': 385.0, 'Type': 'Water'}
# {'Name': 'Poliwrath', 'SpecialAttack': 70.0, 'HP': 90.0, 'Speed': 70.0, 'Attack': 95.0, 'Defense': 95.0, 'PokedexNumber': 62.0, 'SpecialDefense': 90.0, 'Total': 510.0, 'Type': 'WaterFighting'}
# {'Name': 'Abra', 'SpecialAttack': 105.0, 'HP': 25.0, 'Speed': 90.0, 'Attack': 20.0, 'Defense': 15.0, 'PokedexNumber': 63.0, 'SpecialDefense': 55.0, 'Total': 310.0, 'Type': 'Psychic'}
# {'Name': 'Kadabra', 'SpecialAttack': 120.0, 'HP': 40.0, 'Speed': 105.0, 'Attack': 35.0, 'Defense': 30.0, 'PokedexNumber': 64.0, 'SpecialDefense': 70.0, 'Total': 400.0, 'Type': 'Psychic'}
# {'Name': 'Alakazam', 'SpecialAttack': 135.0, 'HP': 55.0, 'Speed': 120.0, 'Attack': 50.0, 'Defense': 45.0, 'PokedexNumber': 65.0, 'SpecialDefense': 95.0, 'Total': 500.0, 'Type': 'Psychic'}
# {'Name': 'AlakazamMega Alakazam', 'SpecialAttack': 175.0, 'HP': 55.0, 'Speed': 150.0, 'Attack': 50.0, 'Defense': 65.0, 'PokedexNumber': 65.0, 'SpecialDefense': 95.0, 'Total': 590.0, 'Type': 'Psychic'}
# {'Name': 'Machop', 'SpecialAttack': 35.0, 'HP': 70.0, 'Speed': 35.0, 'Attack': 80.0, 'Defense': 50.0, 'PokedexNumber': 66.0, 'SpecialDefense': 35.0, 'Total': 305.0, 'Type': 'Fighting'}
# {'Name': 'Machoke', 'SpecialAttack': 50.0, 'HP': 80.0, 'Speed': 45.0, 'Attack': 100.0, 'Defense': 70.0, 'PokedexNumber': 67.0, 'SpecialDefense': 60.0, 'Total': 405.0, 'Type': 'Fighting'}
# {'Name': 'Machamp', 'SpecialAttack': 65.0, 'HP': 90.0, 'Speed': 55.0, 'Attack': 130.0, 'Defense': 80.0, 'PokedexNumber': 68.0, 'SpecialDefense': 85.0, 'Total': 505.0, 'Type': 'Fighting'}
# {'Name': 'Bellsprout', 'SpecialAttack': 70.0, 'HP': 50.0, 'Speed': 40.0, 'Attack': 75.0, 'Defense': 35.0, 'PokedexNumber': 69.0, 'SpecialDefense': 30.0, 'Total': 300.0, 'Type': 'GrassPoison'}
# {'Name': 'Weepinbell', 'SpecialAttack': 85.0, 'HP': 65.0, 'Speed': 55.0, 'Attack': 90.0, 'Defense': 50.0, 'PokedexNumber': 70.0, 'SpecialDefense': 45.0, 'Total': 390.0, 'Type': 'GrassPoison'}
# {'Name': 'Victreebel', 'SpecialAttack': 100.0, 'HP': 80.0, 'Speed': 70.0, 'Attack': 105.0, 'Defense': 65.0, 'PokedexNumber': 71.0, 'SpecialDefense': 70.0, 'Total': 490.0, 'Type': 'GrassPoison'}
# {'Name': 'Tentacool', 'SpecialAttack': 50.0, 'HP': 40.0, 'Speed': 70.0, 'Attack': 40.0, 'Defense': 35.0, 'PokedexNumber': 72.0, 'SpecialDefense': 100.0, 'Total': 335.0, 'Type': 'WaterPoison'}
# {'Name': 'Tentacruel', 'SpecialAttack': 80.0, 'HP': 80.0, 'Speed': 100.0, 'Attack': 70.0, 'Defense': 65.0, 'PokedexNumber': 73.0, 'SpecialDefense': 120.0, 'Total': 515.0, 'Type': 'WaterPoison'}
# {'Name': 'Geodude', 'SpecialAttack': 30.0, 'HP': 40.0, 'Speed': 20.0, 'Attack': 80.0, 'Defense': 100.0, 'PokedexNumber': 74.0, 'SpecialDefense': 30.0, 'Total': 300.0, 'Type': 'RockGround'}
# {'Name': 'Graveler', 'SpecialAttack': 45.0, 'HP': 55.0, 'Speed': 35.0, 'Attack': 95.0, 'Defense': 115.0, 'PokedexNumber': 75.0, 'SpecialDefense': 45.0, 'Total': 390.0, 'Type': 'RockGround'}
# {'Name': 'Golem', 'SpecialAttack': 55.0, 'HP': 80.0, 'Speed': 45.0, 'Attack': 120.0, 'Defense': 130.0, 'PokedexNumber': 76.0, 'SpecialDefense': 65.0, 'Total': 495.0, 'Type': 'RockGround'}
# {'Name': 'Ponyta', 'SpecialAttack': 65.0, 'HP': 50.0, 'Speed': 90.0, 'Attack': 85.0, 'Defense': 55.0, 'PokedexNumber': 77.0, 'SpecialDefense': 65.0, 'Total': 410.0, 'Type': 'Fire'}
# {'Name': 'Rapidash', 'SpecialAttack': 80.0, 'HP': 65.0, 'Speed': 105.0, 'Attack': 100.0, 'Defense': 70.0, 'PokedexNumber': 78.0, 'SpecialDefense': 80.0, 'Total': 500.0, 'Type': 'Fire'}
# {'Name': 'Slowpoke', 'SpecialAttack': 40.0, 'HP': 90.0, 'Speed': 15.0, 'Attack': 65.0, 'Defense': 65.0, 'PokedexNumber': 79.0, 'SpecialDefense': 40.0, 'Total': 315.0, 'Type': 'WaterPsychic'}
# {'Name': 'Slowbro', 'SpecialAttack': 100.0, 'HP': 95.0, 'Speed': 30.0, 'Attack': 75.0, 'Defense': 110.0, 'PokedexNumber': 80.0, 'SpecialDefense': 80.0, 'Total': 490.0, 'Type': 'WaterPsychic'}
# {'Name': 'SlowbroMega Slowbro', 'SpecialAttack': 130.0, 'HP': 95.0, 'Speed': 30.0, 'Attack': 75.0, 'Defense': 180.0, 'PokedexNumber': 80.0, 'SpecialDefense': 80.0, 'Total': 590.0, 'Type': 'WaterPsychic'}
# {'Name': 'Magnemite', 'SpecialAttack': 95.0, 'HP': 25.0, 'Speed': 45.0, 'Attack': 35.0, 'Defense': 70.0, 'PokedexNumber': 81.0, 'SpecialDefense': 55.0, 'Total': 325.0, 'Type': 'ElectricSteel'}
# {'Name': 'Magneton', 'SpecialAttack': 120.0, 'HP': 50.0, 'Speed': 70.0, 'Attack': 60.0, 'Defense': 95.0, 'PokedexNumber': 82.0, 'SpecialDefense': 70.0, 'Total': 465.0, 'Type': 'ElectricSteel'}
# {'Name': "Farfetch'd", 'SpecialAttack': 58.0, 'HP': 52.0, 'Speed': 60.0, 'Attack': 65.0, 'Defense': 55.0, 'PokedexNumber': 83.0, 'SpecialDefense': 62.0, 'Total': 352.0, 'Type': 'NormalFlying'}
# {'Name': 'Doduo', 'SpecialAttack': 35.0, 'HP': 35.0, 'Speed': 75.0, 'Attack': 85.0, 'Defense': 45.0, 'PokedexNumber': 84.0, 'SpecialDefense': 35.0, 'Total': 310.0, 'Type': 'NormalFlying'}
# {'Name': 'Dodrio', 'SpecialAttack': 60.0, 'HP': 60.0, 'Speed': 100.0, 'Attack': 110.0, 'Defense': 70.0, 'PokedexNumber': 85.0, 'SpecialDefense': 60.0, 'Total': 460.0, 'Type': 'NormalFlying'}
# {'Name': 'Seel', 'SpecialAttack': 45.0, 'HP': 65.0, 'Speed': 45.0, 'Attack': 45.0, 'Defense': 55.0, 'PokedexNumber': 86.0, 'SpecialDefense': 70.0, 'Total': 325.0, 'Type': 'Water'}
# {'Name': 'Dewgong', 'SpecialAttack': 70.0, 'HP': 90.0, 'Speed': 70.0, 'Attack': 70.0, 'Defense': 80.0, 'PokedexNumber': 87.0, 'SpecialDefense': 95.0, 'Total': 475.0, 'Type': 'WaterIce'}
# {'Name': 'Grimer', 'SpecialAttack': 40.0, 'HP': 80.0, 'Speed': 25.0, 'Attack': 80.0, 'Defense': 50.0, 'PokedexNumber': 88.0, 'SpecialDefense': 50.0, 'Total': 325.0, 'Type': 'Poison'}
# {'Name': 'Muk', 'SpecialAttack': 65.0, 'HP': 105.0, 'Speed': 50.0, 'Attack': 105.0, 'Defense': 75.0, 'PokedexNumber': 89.0, 'SpecialDefense': 100.0, 'Total': 500.0, 'Type': 'Poison'}
# {'Name': 'Shellder', 'SpecialAttack': 45.0, 'HP': 30.0, 'Speed': 40.0, 'Attack': 65.0, 'Defense': 100.0, 'PokedexNumber': 90.0, 'SpecialDefense': 25.0, 'Total': 305.0, 'Type': 'Water'}
# {'Name': 'Cloyster', 'SpecialAttack': 85.0, 'HP': 50.0, 'Speed': 70.0, 'Attack': 95.0, 'Defense': 180.0, 'PokedexNumber': 91.0, 'SpecialDefense': 45.0, 'Total': 525.0, 'Type': 'WaterIce'}
# {'Name': 'Gastly', 'SpecialAttack': 100.0, 'HP': 30.0, 'Speed': 80.0, 'Attack': 35.0, 'Defense': 30.0, 'PokedexNumber': 92.0, 'SpecialDefense': 35.0, 'Total': 310.0, 'Type': 'GhostPoison'}
# {'Name': 'Haunter', 'SpecialAttack': 115.0, 'HP': 45.0, 'Speed': 95.0, 'Attack': 50.0, 'Defense': 45.0, 'PokedexNumber': 93.0, 'SpecialDefense': 55.0, 'Total': 405.0, 'Type': 'GhostPoison'}
# {'Name': 'Gengar', 'SpecialAttack': 130.0, 'HP': 60.0, 'Speed': 110.0, 'Attack': 65.0, 'Defense': 60.0, 'PokedexNumber': 94.0, 'SpecialDefense': 75.0, 'Total': 500.0, 'Type': 'GhostPoison'}
# {'Name': 'GengarMega Gengar', 'SpecialAttack': 170.0, 'HP': 60.0, 'Speed': 130.0, 'Attack': 65.0, 'Defense': 80.0, 'PokedexNumber': 94.0, 'SpecialDefense': 95.0, 'Total': 600.0, 'Type': 'GhostPoison'}
# {'Name': 'Onix', 'SpecialAttack': 30.0, 'HP': 35.0, 'Speed': 70.0, 'Attack': 45.0, 'Defense': 160.0, 'PokedexNumber': 95.0, 'SpecialDefense': 45.0, 'Total': 385.0, 'Type': 'RockGround'}
# {'Name': 'Drowzee', 'SpecialAttack': 43.0, 'HP': 60.0, 'Speed': 42.0, 'Attack': 48.0, 'Defense': 45.0, 'PokedexNumber': 96.0, 'SpecialDefense': 90.0, 'Total': 328.0, 'Type': 'Psychic'}
# {'Name': 'Hypno', 'SpecialAttack': 73.0, 'HP': 85.0, 'Speed': 67.0, 'Attack': 73.0, 'Defense': 70.0, 'PokedexNumber': 97.0, 'SpecialDefense': 115.0, 'Total': 483.0, 'Type': 'Psychic'}
# {'Name': 'Krabby', 'SpecialAttack': 25.0, 'HP': 30.0, 'Speed': 50.0, 'Attack': 105.0, 'Defense': 90.0, 'PokedexNumber': 98.0, 'SpecialDefense': 25.0, 'Total': 325.0, 'Type': 'Water'}
# {'Name': 'Kingler', 'SpecialAttack': 50.0, 'HP': 55.0, 'Speed': 75.0, 'Attack': 130.0, 'Defense': 115.0, 'PokedexNumber': 99.0, 'SpecialDefense': 50.0, 'Total': 475.0, 'Type': 'Water'}
# {'Name': 'Voltorb', 'SpecialAttack': 55.0, 'HP': 40.0, 'Speed': 100.0, 'Attack': 30.0, 'Defense': 50.0, 'PokedexNumber': 100.0, 'SpecialDefense': 55.0, 'Total': 330.0, 'Type': 'Electric'}
# {'Name': 'Electrode', 'SpecialAttack': 80.0, 'HP': 60.0, 'Speed': 140.0, 'Attack': 50.0, 'Defense': 70.0, 'PokedexNumber': 101.0, 'SpecialDefense': 80.0, 'Total': 480.0, 'Type': 'Electric'}
# {'Name': 'Exeggcute', 'SpecialAttack': 60.0, 'HP': 60.0, 'Speed': 40.0, 'Attack': 40.0, 'Defense': 80.0, 'PokedexNumber': 102.0, 'SpecialDefense': 45.0, 'Total': 325.0, 'Type': 'GrassPsychic'}
# {'Name': 'Exeggutor', 'SpecialAttack': 125.0, 'HP': 95.0, 'Speed': 55.0, 'Attack': 95.0, 'Defense': 85.0, 'PokedexNumber': 103.0, 'SpecialDefense': 65.0, 'Total': 520.0, 'Type': 'GrassPsychic'}
# {'Name': 'Cubone', 'SpecialAttack': 40.0, 'HP': 50.0, 'Speed': 35.0, 'Attack': 50.0, 'Defense': 95.0, 'PokedexNumber': 104.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Ground'}
# {'Name': 'Marowak', 'SpecialAttack': 50.0, 'HP': 60.0, 'Speed': 45.0, 'Attack': 80.0, 'Defense': 110.0, 'PokedexNumber': 105.0, 'SpecialDefense': 80.0, 'Total': 425.0, 'Type': 'Ground'}
# {'Name': 'Hitmonlee', 'SpecialAttack': 35.0, 'HP': 50.0, 'Speed': 87.0, 'Attack': 120.0, 'Defense': 53.0, 'PokedexNumber': 106.0, 'SpecialDefense': 110.0, 'Total': 455.0, 'Type': 'Fighting'}
# {'Name': 'Hitmonchan', 'SpecialAttack': 35.0, 'HP': 50.0, 'Speed': 76.0, 'Attack': 105.0, 'Defense': 79.0, 'PokedexNumber': 107.0, 'SpecialDefense': 110.0, 'Total': 455.0, 'Type': 'Fighting'}
# {'Name': 'Lickitung', 'SpecialAttack': 60.0, 'HP': 90.0, 'Speed': 30.0, 'Attack': 55.0, 'Defense': 75.0, 'PokedexNumber': 108.0, 'SpecialDefense': 75.0, 'Total': 385.0, 'Type': 'Normal'}
# {'Name': 'Koffing', 'SpecialAttack': 60.0, 'HP': 40.0, 'Speed': 35.0, 'Attack': 65.0, 'Defense': 95.0, 'PokedexNumber': 109.0, 'SpecialDefense': 45.0, 'Total': 340.0, 'Type': 'Poison'}
# {'Name': 'Weezing', 'SpecialAttack': 85.0, 'HP': 65.0, 'Speed': 60.0, 'Attack': 90.0, 'Defense': 120.0, 'PokedexNumber': 110.0, 'SpecialDefense': 70.0, 'Total': 490.0, 'Type': 'Poison'}
# {'Name': 'Rhyhorn', 'SpecialAttack': 30.0, 'HP': 80.0, 'Speed': 25.0, 'Attack': 85.0, 'Defense': 95.0, 'PokedexNumber': 111.0, 'SpecialDefense': 30.0, 'Total': 345.0, 'Type': 'GroundRock'}
# {'Name': 'Rhydon', 'SpecialAttack': 45.0, 'HP': 105.0, 'Speed': 40.0, 'Attack': 130.0, 'Defense': 120.0, 'PokedexNumber': 112.0, 'SpecialDefense': 45.0, 'Total': 485.0, 'Type': 'GroundRock'}
# {'Name': 'Chansey', 'SpecialAttack': 35.0, 'HP': 250.0, 'Speed': 50.0, 'Attack': 5.0, 'Defense': 5.0, 'PokedexNumber': 113.0, 'SpecialDefense': 105.0, 'Total': 450.0, 'Type': 'Normal'}
# {'Name': 'Tangela', 'SpecialAttack': 100.0, 'HP': 65.0, 'Speed': 60.0, 'Attack': 55.0, 'Defense': 115.0, 'PokedexNumber': 114.0, 'SpecialDefense': 40.0, 'Total': 435.0, 'Type': 'Grass'}
# {'Name': 'Kangaskhan', 'SpecialAttack': 40.0, 'HP': 105.0, 'Speed': 90.0, 'Attack': 95.0, 'Defense': 80.0, 'PokedexNumber': 115.0, 'SpecialDefense': 80.0, 'Total': 490.0, 'Type': 'Normal'}
# {'Name': 'KangaskhanMega Kangaskhan', 'SpecialAttack': 60.0, 'HP': 105.0, 'Speed': 100.0, 'Attack': 125.0, 'Defense': 100.0, 'PokedexNumber': 115.0, 'SpecialDefense': 100.0, 'Total': 590.0, 'Type': 'Normal'}
# {'Name': 'Horsea', 'SpecialAttack': 70.0, 'HP': 30.0, 'Speed': 60.0, 'Attack': 40.0, 'Defense': 70.0, 'PokedexNumber': 116.0, 'SpecialDefense': 25.0, 'Total': 295.0, 'Type': 'Water'}
# {'Name': 'Seadra', 'SpecialAttack': 95.0, 'HP': 55.0, 'Speed': 85.0, 'Attack': 65.0, 'Defense': 95.0, 'PokedexNumber': 117.0, 'SpecialDefense': 45.0, 'Total': 440.0, 'Type': 'Water'}
# {'Name': 'Goldeen', 'SpecialAttack': 35.0, 'HP': 45.0, 'Speed': 63.0, 'Attack': 67.0, 'Defense': 60.0, 'PokedexNumber': 118.0, 'SpecialDefense': 50.0, 'Total': 320.0, 'Type': 'Water'}
# {'Name': 'Seaking', 'SpecialAttack': 65.0, 'HP': 80.0, 'Speed': 68.0, 'Attack': 92.0, 'Defense': 65.0, 'PokedexNumber': 119.0, 'SpecialDefense': 80.0, 'Total': 450.0, 'Type': 'Water'}
# {'Name': 'Staryu', 'SpecialAttack': 70.0, 'HP': 30.0, 'Speed': 85.0, 'Attack': 45.0, 'Defense': 55.0, 'PokedexNumber': 120.0, 'SpecialDefense': 55.0, 'Total': 340.0, 'Type': 'Water'}
# {'Name': 'Starmie', 'SpecialAttack': 100.0, 'HP': 60.0, 'Speed': 115.0, 'Attack': 75.0, 'Defense': 85.0, 'PokedexNumber': 121.0, 'SpecialDefense': 85.0, 'Total': 520.0, 'Type': 'WaterPsychic'}
# {'Name': 'Mr. Mime', 'SpecialAttack': 100.0, 'HP': 40.0, 'Speed': 90.0, 'Attack': 45.0, 'Defense': 65.0, 'PokedexNumber': 122.0, 'SpecialDefense': 120.0, 'Total': 460.0, 'Type': 'PsychicFairy'}
# {'Name': 'Scyther', 'SpecialAttack': 55.0, 'HP': 70.0, 'Speed': 105.0, 'Attack': 110.0, 'Defense': 80.0, 'PokedexNumber': 123.0, 'SpecialDefense': 80.0, 'Total': 500.0, 'Type': 'BugFlying'}
# {'Name': 'Jynx', 'SpecialAttack': 115.0, 'HP': 65.0, 'Speed': 95.0, 'Attack': 50.0, 'Defense': 35.0, 'PokedexNumber': 124.0, 'SpecialDefense': 95.0, 'Total': 455.0, 'Type': 'IcePsychic'}
# {'Name': 'Electabuzz', 'SpecialAttack': 95.0, 'HP': 65.0, 'Speed': 105.0, 'Attack': 83.0, 'Defense': 57.0, 'PokedexNumber': 125.0, 'SpecialDefense': 85.0, 'Total': 490.0, 'Type': 'Electric'}
# {'Name': 'Magmar', 'SpecialAttack': 100.0, 'HP': 65.0, 'Speed': 93.0, 'Attack': 95.0, 'Defense': 57.0, 'PokedexNumber': 126.0, 'SpecialDefense': 85.0, 'Total': 495.0, 'Type': 'Fire'}
# {'Name': 'Pinsir', 'SpecialAttack': 55.0, 'HP': 65.0, 'Speed': 85.0, 'Attack': 125.0, 'Defense': 100.0, 'PokedexNumber': 127.0, 'SpecialDefense': 70.0, 'Total': 500.0, 'Type': 'Bug'}
# {'Name': 'PinsirMega Pinsir', 'SpecialAttack': 65.0, 'HP': 65.0, 'Speed': 105.0, 'Attack': 155.0, 'Defense': 120.0, 'PokedexNumber': 127.0, 'SpecialDefense': 90.0, 'Total': 600.0, 'Type': 'BugFlying'}
# {'Name': 'Tauros', 'SpecialAttack': 40.0, 'HP': 75.0, 'Speed': 110.0, 'Attack': 100.0, 'Defense': 95.0, 'PokedexNumber': 128.0, 'SpecialDefense': 70.0, 'Total': 490.0, 'Type': 'Normal'}
# {'Name': 'Magikarp', 'SpecialAttack': 15.0, 'HP': 20.0, 'Speed': 80.0, 'Attack': 10.0, 'Defense': 55.0, 'PokedexNumber': 129.0, 'SpecialDefense': 20.0, 'Total': 200.0, 'Type': 'Water'}
# {'Name': 'Gyarados', 'SpecialAttack': 60.0, 'HP': 95.0, 'Speed': 81.0, 'Attack': 125.0, 'Defense': 79.0, 'PokedexNumber': 130.0, 'SpecialDefense': 100.0, 'Total': 540.0, 'Type': 'WaterFlying'}
# {'Name': 'GyaradosMega Gyarados', 'SpecialAttack': 70.0, 'HP': 95.0, 'Speed': 81.0, 'Attack': 155.0, 'Defense': 109.0, 'PokedexNumber': 130.0, 'SpecialDefense': 130.0, 'Total': 640.0, 'Type': 'WaterDark'}
# {'Name': 'Lapras', 'SpecialAttack': 85.0, 'HP': 130.0, 'Speed': 60.0, 'Attack': 85.0, 'Defense': 80.0, 'PokedexNumber': 131.0, 'SpecialDefense': 95.0, 'Total': 535.0, 'Type': 'WaterIce'}
# {'Name': 'Ditto', 'SpecialAttack': 48.0, 'HP': 48.0, 'Speed': 48.0, 'Attack': 48.0, 'Defense': 48.0, 'PokedexNumber': 132.0, 'SpecialDefense': 48.0, 'Total': 288.0, 'Type': 'Normal'}
# {'Name': 'Eevee', 'SpecialAttack': 45.0, 'HP': 55.0, 'Speed': 55.0, 'Attack': 55.0, 'Defense': 50.0, 'PokedexNumber': 133.0, 'SpecialDefense': 65.0, 'Total': 325.0, 'Type': 'Normal'}
# {'Name': 'Vaporeon', 'SpecialAttack': 110.0, 'HP': 130.0, 'Speed': 65.0, 'Attack': 65.0, 'Defense': 60.0, 'PokedexNumber': 134.0, 'SpecialDefense': 95.0, 'Total': 525.0, 'Type': 'Water'}
# {'Name': 'Jolteon', 'SpecialAttack': 110.0, 'HP': 65.0, 'Speed': 130.0, 'Attack': 65.0, 'Defense': 60.0, 'PokedexNumber': 135.0, 'SpecialDefense': 95.0, 'Total': 525.0, 'Type': 'Electric'}
# {'Name': 'Flareon', 'SpecialAttack': 95.0, 'HP': 65.0, 'Speed': 65.0, 'Attack': 130.0, 'Defense': 60.0, 'PokedexNumber': 136.0, 'SpecialDefense': 110.0, 'Total': 525.0, 'Type': 'Fire'}
# {'Name': 'Porygon', 'SpecialAttack': 85.0, 'HP': 65.0, 'Speed': 40.0, 'Attack': 60.0, 'Defense': 70.0, 'PokedexNumber': 137.0, 'SpecialDefense': 75.0, 'Total': 395.0, 'Type': 'Normal'}
# {'Name': 'Omanyte', 'SpecialAttack': 90.0, 'HP': 35.0, 'Speed': 35.0, 'Attack': 40.0, 'Defense': 100.0, 'PokedexNumber': 138.0, 'SpecialDefense': 55.0, 'Total': 355.0, 'Type': 'RockWater'}
# {'Name': 'Omastar', 'SpecialAttack': 115.0, 'HP': 70.0, 'Speed': 55.0, 'Attack': 60.0, 'Defense': 125.0, 'PokedexNumber': 139.0, 'SpecialDefense': 70.0, 'Total': 495.0, 'Type': 'RockWater'}
# {'Name': 'Kabuto', 'SpecialAttack': 55.0, 'HP': 30.0, 'Speed': 55.0, 'Attack': 80.0, 'Defense': 90.0, 'PokedexNumber': 140.0, 'SpecialDefense': 45.0, 'Total': 355.0, 'Type': 'RockWater'}
# {'Name': 'Kabutops', 'SpecialAttack': 65.0, 'HP': 60.0, 'Speed': 80.0, 'Attack': 115.0, 'Defense': 105.0, 'PokedexNumber': 141.0, 'SpecialDefense': 70.0, 'Total': 495.0, 'Type': 'RockWater'}
# {'Name': 'Aerodactyl', 'SpecialAttack': 60.0, 'HP': 80.0, 'Speed': 130.0, 'Attack': 105.0, 'Defense': 65.0, 'PokedexNumber': 142.0, 'SpecialDefense': 75.0, 'Total': 515.0, 'Type': 'RockFlying'}
# {'Name': 'AerodactylMega Aerodactyl', 'SpecialAttack': 70.0, 'HP': 80.0, 'Speed': 150.0, 'Attack': 135.0, 'Defense': 85.0, 'PokedexNumber': 142.0, 'SpecialDefense': 95.0, 'Total': 615.0, 'Type': 'RockFlying'}
# {'Name': 'Snorlax', 'SpecialAttack': 65.0, 'HP': 160.0, 'Speed': 30.0, 'Attack': 110.0, 'Defense': 65.0, 'PokedexNumber': 143.0, 'SpecialDefense': 110.0, 'Total': 540.0, 'Type': 'Normal'}
# {'Name': 'Articuno', 'SpecialAttack': 95.0, 'HP': 90.0, 'Speed': 85.0, 'Attack': 85.0, 'Defense': 100.0, 'PokedexNumber': 144.0, 'SpecialDefense': 125.0, 'Total': 580.0, 'Type': 'IceFlying'}
# {'Name': 'Zapdos', 'SpecialAttack': 125.0, 'HP': 90.0, 'Speed': 100.0, 'Attack': 90.0, 'Defense': 85.0, 'PokedexNumber': 145.0, 'SpecialDefense': 90.0, 'Total': 580.0, 'Type': 'ElectricFlying'}
# {'Name': 'Moltres', 'SpecialAttack': 125.0, 'HP': 90.0, 'Speed': 90.0, 'Attack': 100.0, 'Defense': 90.0, 'PokedexNumber': 146.0, 'SpecialDefense': 85.0, 'Total': 580.0, 'Type': 'FireFlying'}
# {'Name': 'Dratini', 'SpecialAttack': 50.0, 'HP': 41.0, 'Speed': 50.0, 'Attack': 64.0, 'Defense': 45.0, 'PokedexNumber': 147.0, 'SpecialDefense': 50.0, 'Total': 300.0, 'Type': 'Dragon'}
# {'Name': 'Dragonair', 'SpecialAttack': 70.0, 'HP': 61.0, 'Speed': 70.0, 'Attack': 84.0, 'Defense': 65.0, 'PokedexNumber': 148.0, 'SpecialDefense': 70.0, 'Total': 420.0, 'Type': 'Dragon'}
# {'Name': 'Dragonite', 'SpecialAttack': 100.0, 'HP': 91.0, 'Speed': 80.0, 'Attack': 134.0, 'Defense': 95.0, 'PokedexNumber': 149.0, 'SpecialDefense': 100.0, 'Total': 600.0, 'Type': 'DragonFlying'}
# {'Name': 'Mewtwo', 'SpecialAttack': 154.0, 'HP': 106.0, 'Speed': 130.0, 'Attack': 110.0, 'Defense': 90.0, 'PokedexNumber': 150.0, 'SpecialDefense': 90.0, 'Total': 680.0, 'Type': 'Psychic'}
# {'Name': 'MewtwoMega Mewtwo X', 'SpecialAttack': 154.0, 'HP': 106.0, 'Speed': 130.0, 'Attack': 190.0, 'Defense': 100.0, 'PokedexNumber': 150.0, 'SpecialDefense': 100.0, 'Total': 780.0, 'Type': 'PsychicFighting'}
# {'Name': 'MewtwoMega Mewtwo Y', 'SpecialAttack': 194.0, 'HP': 106.0, 'Speed': 140.0, 'Attack': 150.0, 'Defense': 70.0, 'PokedexNumber': 150.0, 'SpecialDefense': 120.0, 'Total': 780.0, 'Type': 'Psychic'}
# {'Name': 'Mew', 'SpecialAttack': 100.0, 'HP': 100.0, 'Speed': 100.0, 'Attack': 100.0, 'Defense': 100.0, 'PokedexNumber': 151.0, 'SpecialDefense': 100.0, 'Total': 600.0, 'Type': 'Psychic'}
# {'Name': 'Chikorita', 'SpecialAttack': 49.0, 'HP': 45.0, 'Speed': 45.0, 'Attack': 49.0, 'Defense': 65.0, 'PokedexNumber': 152.0, 'SpecialDefense': 65.0, 'Total': 318.0, 'Type': 'Grass'}
# {'Name': 'Bayleef', 'SpecialAttack': 63.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 62.0, 'Defense': 80.0, 'PokedexNumber': 153.0, 'SpecialDefense': 80.0, 'Total': 405.0, 'Type': 'Grass'}
# {'Name': 'Meganium', 'SpecialAttack': 83.0, 'HP': 80.0, 'Speed': 80.0, 'Attack': 82.0, 'Defense': 100.0, 'PokedexNumber': 154.0, 'SpecialDefense': 100.0, 'Total': 525.0, 'Type': 'Grass'}
# {'Name': 'Cyndaquil', 'SpecialAttack': 60.0, 'HP': 39.0, 'Speed': 65.0, 'Attack': 52.0, 'Defense': 43.0, 'PokedexNumber': 155.0, 'SpecialDefense': 50.0, 'Total': 309.0, 'Type': 'Fire'}
# {'Name': 'Quilava', 'SpecialAttack': 80.0, 'HP': 58.0, 'Speed': 80.0, 'Attack': 64.0, 'Defense': 58.0, 'PokedexNumber': 156.0, 'SpecialDefense': 65.0, 'Total': 405.0, 'Type': 'Fire'}
# {'Name': 'Typhlosion', 'SpecialAttack': 109.0, 'HP': 78.0, 'Speed': 100.0, 'Attack': 84.0, 'Defense': 78.0, 'PokedexNumber': 157.0, 'SpecialDefense': 85.0, 'Total': 534.0, 'Type': 'Fire'}
# {'Name': 'Totodile', 'SpecialAttack': 44.0, 'HP': 50.0, 'Speed': 43.0, 'Attack': 65.0, 'Defense': 64.0, 'PokedexNumber': 158.0, 'SpecialDefense': 48.0, 'Total': 314.0, 'Type': 'Water'}
# {'Name': 'Croconaw', 'SpecialAttack': 59.0, 'HP': 65.0, 'Speed': 58.0, 'Attack': 80.0, 'Defense': 80.0, 'PokedexNumber': 159.0, 'SpecialDefense': 63.0, 'Total': 405.0, 'Type': 'Water'}
# {'Name': 'Feraligatr', 'SpecialAttack': 79.0, 'HP': 85.0, 'Speed': 78.0, 'Attack': 105.0, 'Defense': 100.0, 'PokedexNumber': 160.0, 'SpecialDefense': 83.0, 'Total': 530.0, 'Type': 'Water'}
# {'Name': 'Sentret', 'SpecialAttack': 35.0, 'HP': 35.0, 'Speed': 20.0, 'Attack': 46.0, 'Defense': 34.0, 'PokedexNumber': 161.0, 'SpecialDefense': 45.0, 'Total': 215.0, 'Type': 'Normal'}
# {'Name': 'Furret', 'SpecialAttack': 45.0, 'HP': 85.0, 'Speed': 90.0, 'Attack': 76.0, 'Defense': 64.0, 'PokedexNumber': 162.0, 'SpecialDefense': 55.0, 'Total': 415.0, 'Type': 'Normal'}
# {'Name': 'Hoothoot', 'SpecialAttack': 36.0, 'HP': 60.0, 'Speed': 50.0, 'Attack': 30.0, 'Defense': 30.0, 'PokedexNumber': 163.0, 'SpecialDefense': 56.0, 'Total': 262.0, 'Type': 'NormalFlying'}
# {'Name': 'Noctowl', 'SpecialAttack': 76.0, 'HP': 100.0, 'Speed': 70.0, 'Attack': 50.0, 'Defense': 50.0, 'PokedexNumber': 164.0, 'SpecialDefense': 96.0, 'Total': 442.0, 'Type': 'NormalFlying'}
# {'Name': 'Ledyba', 'SpecialAttack': 40.0, 'HP': 40.0, 'Speed': 55.0, 'Attack': 20.0, 'Defense': 30.0, 'PokedexNumber': 165.0, 'SpecialDefense': 80.0, 'Total': 265.0, 'Type': 'BugFlying'}
# {'Name': 'Ledian', 'SpecialAttack': 55.0, 'HP': 55.0, 'Speed': 85.0, 'Attack': 35.0, 'Defense': 50.0, 'PokedexNumber': 166.0, 'SpecialDefense': 110.0, 'Total': 390.0, 'Type': 'BugFlying'}
# {'Name': 'Spinarak', 'SpecialAttack': 40.0, 'HP': 40.0, 'Speed': 30.0, 'Attack': 60.0, 'Defense': 40.0, 'PokedexNumber': 167.0, 'SpecialDefense': 40.0, 'Total': 250.0, 'Type': 'BugPoison'}
# {'Name': 'Ariados', 'SpecialAttack': 60.0, 'HP': 70.0, 'Speed': 40.0, 'Attack': 90.0, 'Defense': 70.0, 'PokedexNumber': 168.0, 'SpecialDefense': 60.0, 'Total': 390.0, 'Type': 'BugPoison'}
# {'Name': 'Crobat', 'SpecialAttack': 70.0, 'HP': 85.0, 'Speed': 130.0, 'Attack': 90.0, 'Defense': 80.0, 'PokedexNumber': 169.0, 'SpecialDefense': 80.0, 'Total': 535.0, 'Type': 'PoisonFlying'}
# {'Name': 'Chinchou', 'SpecialAttack': 56.0, 'HP': 75.0, 'Speed': 67.0, 'Attack': 38.0, 'Defense': 38.0, 'PokedexNumber': 170.0, 'SpecialDefense': 56.0, 'Total': 330.0, 'Type': 'WaterElectric'}
# {'Name': 'Lanturn', 'SpecialAttack': 76.0, 'HP': 125.0, 'Speed': 67.0, 'Attack': 58.0, 'Defense': 58.0, 'PokedexNumber': 171.0, 'SpecialDefense': 76.0, 'Total': 460.0, 'Type': 'WaterElectric'}
# {'Name': 'Pichu', 'SpecialAttack': 35.0, 'HP': 20.0, 'Speed': 60.0, 'Attack': 40.0, 'Defense': 15.0, 'PokedexNumber': 172.0, 'SpecialDefense': 35.0, 'Total': 205.0, 'Type': 'Electric'}
# {'Name': 'Cleffa', 'SpecialAttack': 45.0, 'HP': 50.0, 'Speed': 15.0, 'Attack': 25.0, 'Defense': 28.0, 'PokedexNumber': 173.0, 'SpecialDefense': 55.0, 'Total': 218.0, 'Type': 'Fairy'}
# {'Name': 'Igglybuff', 'SpecialAttack': 40.0, 'HP': 90.0, 'Speed': 15.0, 'Attack': 30.0, 'Defense': 15.0, 'PokedexNumber': 174.0, 'SpecialDefense': 20.0, 'Total': 210.0, 'Type': 'NormalFairy'}
# {'Name': 'Togepi', 'SpecialAttack': 40.0, 'HP': 35.0, 'Speed': 20.0, 'Attack': 20.0, 'Defense': 65.0, 'PokedexNumber': 175.0, 'SpecialDefense': 65.0, 'Total': 245.0, 'Type': 'Fairy'}
# {'Name': 'Togetic', 'SpecialAttack': 80.0, 'HP': 55.0, 'Speed': 40.0, 'Attack': 40.0, 'Defense': 85.0, 'PokedexNumber': 176.0, 'SpecialDefense': 105.0, 'Total': 405.0, 'Type': 'FairyFlying'}
# {'Name': 'Natu', 'SpecialAttack': 70.0, 'HP': 40.0, 'Speed': 70.0, 'Attack': 50.0, 'Defense': 45.0, 'PokedexNumber': 177.0, 'SpecialDefense': 45.0, 'Total': 320.0, 'Type': 'PsychicFlying'}
# {'Name': 'Xatu', 'SpecialAttack': 95.0, 'HP': 65.0, 'Speed': 95.0, 'Attack': 75.0, 'Defense': 70.0, 'PokedexNumber': 178.0, 'SpecialDefense': 70.0, 'Total': 470.0, 'Type': 'PsychicFlying'}
# {'Name': 'Mareep', 'SpecialAttack': 65.0, 'HP': 55.0, 'Speed': 35.0, 'Attack': 40.0, 'Defense': 40.0, 'PokedexNumber': 179.0, 'SpecialDefense': 45.0, 'Total': 280.0, 'Type': 'Electric'}
# {'Name': 'Flaaffy', 'SpecialAttack': 80.0, 'HP': 70.0, 'Speed': 45.0, 'Attack': 55.0, 'Defense': 55.0, 'PokedexNumber': 180.0, 'SpecialDefense': 60.0, 'Total': 365.0, 'Type': 'Electric'}
# {'Name': 'Ampharos', 'SpecialAttack': 115.0, 'HP': 90.0, 'Speed': 55.0, 'Attack': 75.0, 'Defense': 85.0, 'PokedexNumber': 181.0, 'SpecialDefense': 90.0, 'Total': 510.0, 'Type': 'Electric'}
# {'Name': 'AmpharosMega Ampharos', 'SpecialAttack': 165.0, 'HP': 90.0, 'Speed': 45.0, 'Attack': 95.0, 'Defense': 105.0, 'PokedexNumber': 181.0, 'SpecialDefense': 110.0, 'Total': 610.0, 'Type': 'ElectricDragon'}
# {'Name': 'Bellossom', 'SpecialAttack': 90.0, 'HP': 75.0, 'Speed': 50.0, 'Attack': 80.0, 'Defense': 95.0, 'PokedexNumber': 182.0, 'SpecialDefense': 100.0, 'Total': 490.0, 'Type': 'Grass'}
# {'Name': 'Marill', 'SpecialAttack': 20.0, 'HP': 70.0, 'Speed': 40.0, 'Attack': 20.0, 'Defense': 50.0, 'PokedexNumber': 183.0, 'SpecialDefense': 50.0, 'Total': 250.0, 'Type': 'WaterFairy'}
# {'Name': 'Azumarill', 'SpecialAttack': 60.0, 'HP': 100.0, 'Speed': 50.0, 'Attack': 50.0, 'Defense': 80.0, 'PokedexNumber': 184.0, 'SpecialDefense': 80.0, 'Total': 420.0, 'Type': 'WaterFairy'}
# {'Name': 'Sudowoodo', 'SpecialAttack': 30.0, 'HP': 70.0, 'Speed': 30.0, 'Attack': 100.0, 'Defense': 115.0, 'PokedexNumber': 185.0, 'SpecialDefense': 65.0, 'Total': 410.0, 'Type': 'Rock'}
# {'Name': 'Politoed', 'SpecialAttack': 90.0, 'HP': 90.0, 'Speed': 70.0, 'Attack': 75.0, 'Defense': 75.0, 'PokedexNumber': 186.0, 'SpecialDefense': 100.0, 'Total': 500.0, 'Type': 'Water'}
# {'Name': 'Hoppip', 'SpecialAttack': 35.0, 'HP': 35.0, 'Speed': 50.0, 'Attack': 35.0, 'Defense': 40.0, 'PokedexNumber': 187.0, 'SpecialDefense': 55.0, 'Total': 250.0, 'Type': 'GrassFlying'}
# {'Name': 'Skiploom', 'SpecialAttack': 45.0, 'HP': 55.0, 'Speed': 80.0, 'Attack': 45.0, 'Defense': 50.0, 'PokedexNumber': 188.0, 'SpecialDefense': 65.0, 'Total': 340.0, 'Type': 'GrassFlying'}
# {'Name': 'Jumpluff', 'SpecialAttack': 55.0, 'HP': 75.0, 'Speed': 110.0, 'Attack': 55.0, 'Defense': 70.0, 'PokedexNumber': 189.0, 'SpecialDefense': 95.0, 'Total': 460.0, 'Type': 'GrassFlying'}
# {'Name': 'Aipom', 'SpecialAttack': 40.0, 'HP': 55.0, 'Speed': 85.0, 'Attack': 70.0, 'Defense': 55.0, 'PokedexNumber': 190.0, 'SpecialDefense': 55.0, 'Total': 360.0, 'Type': 'Normal'}
# {'Name': 'Sunkern', 'SpecialAttack': 30.0, 'HP': 30.0, 'Speed': 30.0, 'Attack': 30.0, 'Defense': 30.0, 'PokedexNumber': 191.0, 'SpecialDefense': 30.0, 'Total': 180.0, 'Type': 'Grass'}
# {'Name': 'Sunflora', 'SpecialAttack': 105.0, 'HP': 75.0, 'Speed': 30.0, 'Attack': 75.0, 'Defense': 55.0, 'PokedexNumber': 192.0, 'SpecialDefense': 85.0, 'Total': 425.0, 'Type': 'Grass'}
# {'Name': 'Yanma', 'SpecialAttack': 75.0, 'HP': 65.0, 'Speed': 95.0, 'Attack': 65.0, 'Defense': 45.0, 'PokedexNumber': 193.0, 'SpecialDefense': 45.0, 'Total': 390.0, 'Type': 'BugFlying'}
# {'Name': 'Wooper', 'SpecialAttack': 25.0, 'HP': 55.0, 'Speed': 15.0, 'Attack': 45.0, 'Defense': 45.0, 'PokedexNumber': 194.0, 'SpecialDefense': 25.0, 'Total': 210.0, 'Type': 'WaterGround'}
# {'Name': 'Quagsire', 'SpecialAttack': 65.0, 'HP': 95.0, 'Speed': 35.0, 'Attack': 85.0, 'Defense': 85.0, 'PokedexNumber': 195.0, 'SpecialDefense': 65.0, 'Total': 430.0, 'Type': 'WaterGround'}
# {'Name': 'Espeon', 'SpecialAttack': 130.0, 'HP': 65.0, 'Speed': 110.0, 'Attack': 65.0, 'Defense': 60.0, 'PokedexNumber': 196.0, 'SpecialDefense': 95.0, 'Total': 525.0, 'Type': 'Psychic'}
# {'Name': 'Umbreon', 'SpecialAttack': 60.0, 'HP': 95.0, 'Speed': 65.0, 'Attack': 65.0, 'Defense': 110.0, 'PokedexNumber': 197.0, 'SpecialDefense': 130.0, 'Total': 525.0, 'Type': 'Dark'}
# {'Name': 'Murkrow', 'SpecialAttack': 85.0, 'HP': 60.0, 'Speed': 91.0, 'Attack': 85.0, 'Defense': 42.0, 'PokedexNumber': 198.0, 'SpecialDefense': 42.0, 'Total': 405.0, 'Type': 'DarkFlying'}
# {'Name': 'Slowking', 'SpecialAttack': 100.0, 'HP': 95.0, 'Speed': 30.0, 'Attack': 75.0, 'Defense': 80.0, 'PokedexNumber': 199.0, 'SpecialDefense': 110.0, 'Total': 490.0, 'Type': 'WaterPsychic'}
# {'Name': 'Misdreavus', 'SpecialAttack': 85.0, 'HP': 60.0, 'Speed': 85.0, 'Attack': 60.0, 'Defense': 60.0, 'PokedexNumber': 200.0, 'SpecialDefense': 85.0, 'Total': 435.0, 'Type': 'Ghost'}
# {'Name': 'Unown', 'SpecialAttack': 72.0, 'HP': 48.0, 'Speed': 48.0, 'Attack': 72.0, 'Defense': 48.0, 'PokedexNumber': 201.0, 'SpecialDefense': 48.0, 'Total': 336.0, 'Type': 'Psychic'}
# {'Name': 'Wobbuffet', 'SpecialAttack': 33.0, 'HP': 190.0, 'Speed': 33.0, 'Attack': 33.0, 'Defense': 58.0, 'PokedexNumber': 202.0, 'SpecialDefense': 58.0, 'Total': 405.0, 'Type': 'Psychic'}
# {'Name': 'Girafarig', 'SpecialAttack': 90.0, 'HP': 70.0, 'Speed': 85.0, 'Attack': 80.0, 'Defense': 65.0, 'PokedexNumber': 203.0, 'SpecialDefense': 65.0, 'Total': 455.0, 'Type': 'NormalPsychic'}
# {'Name': 'Pineco', 'SpecialAttack': 35.0, 'HP': 50.0, 'Speed': 15.0, 'Attack': 65.0, 'Defense': 90.0, 'PokedexNumber': 204.0, 'SpecialDefense': 35.0, 'Total': 290.0, 'Type': 'Bug'}
# {'Name': 'Forretress', 'SpecialAttack': 60.0, 'HP': 75.0, 'Speed': 40.0, 'Attack': 90.0, 'Defense': 140.0, 'PokedexNumber': 205.0, 'SpecialDefense': 60.0, 'Total': 465.0, 'Type': 'BugSteel'}
# {'Name': 'Dunsparce', 'SpecialAttack': 65.0, 'HP': 100.0, 'Speed': 45.0, 'Attack': 70.0, 'Defense': 70.0, 'PokedexNumber': 206.0, 'SpecialDefense': 65.0, 'Total': 415.0, 'Type': 'Normal'}
# {'Name': 'Gligar', 'SpecialAttack': 35.0, 'HP': 65.0, 'Speed': 85.0, 'Attack': 75.0, 'Defense': 105.0, 'PokedexNumber': 207.0, 'SpecialDefense': 65.0, 'Total': 430.0, 'Type': 'GroundFlying'}
# {'Name': 'Steelix', 'SpecialAttack': 55.0, 'HP': 75.0, 'Speed': 30.0, 'Attack': 85.0, 'Defense': 200.0, 'PokedexNumber': 208.0, 'SpecialDefense': 65.0, 'Total': 510.0, 'Type': 'SteelGround'}
# {'Name': 'SteelixMega Steelix', 'SpecialAttack': 55.0, 'HP': 75.0, 'Speed': 30.0, 'Attack': 125.0, 'Defense': 230.0, 'PokedexNumber': 208.0, 'SpecialDefense': 95.0, 'Total': 610.0, 'Type': 'SteelGround'}
# {'Name': 'Snubbull', 'SpecialAttack': 40.0, 'HP': 60.0, 'Speed': 30.0, 'Attack': 80.0, 'Defense': 50.0, 'PokedexNumber': 209.0, 'SpecialDefense': 40.0, 'Total': 300.0, 'Type': 'Fairy'}
# {'Name': 'Granbull', 'SpecialAttack': 60.0, 'HP': 90.0, 'Speed': 45.0, 'Attack': 120.0, 'Defense': 75.0, 'PokedexNumber': 210.0, 'SpecialDefense': 60.0, 'Total': 450.0, 'Type': 'Fairy'}
# {'Name': 'Qwilfish', 'SpecialAttack': 55.0, 'HP': 65.0, 'Speed': 85.0, 'Attack': 95.0, 'Defense': 75.0, 'PokedexNumber': 211.0, 'SpecialDefense': 55.0, 'Total': 430.0, 'Type': 'WaterPoison'}
# {'Name': 'Scizor', 'SpecialAttack': 55.0, 'HP': 70.0, 'Speed': 65.0, 'Attack': 130.0, 'Defense': 100.0, 'PokedexNumber': 212.0, 'SpecialDefense': 80.0, 'Total': 500.0, 'Type': 'BugSteel'}
# {'Name': 'ScizorMega Scizor', 'SpecialAttack': 65.0, 'HP': 70.0, 'Speed': 75.0, 'Attack': 150.0, 'Defense': 140.0, 'PokedexNumber': 212.0, 'SpecialDefense': 100.0, 'Total': 600.0, 'Type': 'BugSteel'}
# {'Name': 'Shuckle', 'SpecialAttack': 10.0, 'HP': 20.0, 'Speed': 5.0, 'Attack': 10.0, 'Defense': 230.0, 'PokedexNumber': 213.0, 'SpecialDefense': 230.0, 'Total': 505.0, 'Type': 'BugRock'}
# {'Name': 'Heracross', 'SpecialAttack': 40.0, 'HP': 80.0, 'Speed': 85.0, 'Attack': 125.0, 'Defense': 75.0, 'PokedexNumber': 214.0, 'SpecialDefense': 95.0, 'Total': 500.0, 'Type': 'BugFighting'}
# {'Name': 'HeracrossMega Heracross', 'SpecialAttack': 40.0, 'HP': 80.0, 'Speed': 75.0, 'Attack': 185.0, 'Defense': 115.0, 'PokedexNumber': 214.0, 'SpecialDefense': 105.0, 'Total': 600.0, 'Type': 'BugFighting'}
# {'Name': 'Sneasel', 'SpecialAttack': 35.0, 'HP': 55.0, 'Speed': 115.0, 'Attack': 95.0, 'Defense': 55.0, 'PokedexNumber': 215.0, 'SpecialDefense': 75.0, 'Total': 430.0, 'Type': 'DarkIce'}
# {'Name': 'Teddiursa', 'SpecialAttack': 50.0, 'HP': 60.0, 'Speed': 40.0, 'Attack': 80.0, 'Defense': 50.0, 'PokedexNumber': 216.0, 'SpecialDefense': 50.0, 'Total': 330.0, 'Type': 'Normal'}
# {'Name': 'Ursaring', 'SpecialAttack': 75.0, 'HP': 90.0, 'Speed': 55.0, 'Attack': 130.0, 'Defense': 75.0, 'PokedexNumber': 217.0, 'SpecialDefense': 75.0, 'Total': 500.0, 'Type': 'Normal'}
# {'Name': 'Slugma', 'SpecialAttack': 70.0, 'HP': 40.0, 'Speed': 20.0, 'Attack': 40.0, 'Defense': 40.0, 'PokedexNumber': 218.0, 'SpecialDefense': 40.0, 'Total': 250.0, 'Type': 'Fire'}
# {'Name': 'Magcargo', 'SpecialAttack': 80.0, 'HP': 50.0, 'Speed': 30.0, 'Attack': 50.0, 'Defense': 120.0, 'PokedexNumber': 219.0, 'SpecialDefense': 80.0, 'Total': 410.0, 'Type': 'FireRock'}
# {'Name': 'Swinub', 'SpecialAttack': 30.0, 'HP': 50.0, 'Speed': 50.0, 'Attack': 50.0, 'Defense': 40.0, 'PokedexNumber': 220.0, 'SpecialDefense': 30.0, 'Total': 250.0, 'Type': 'IceGround'}
# {'Name': 'Piloswine', 'SpecialAttack': 60.0, 'HP': 100.0, 'Speed': 50.0, 'Attack': 100.0, 'Defense': 80.0, 'PokedexNumber': 221.0, 'SpecialDefense': 60.0, 'Total': 450.0, 'Type': 'IceGround'}
# {'Name': 'Corsola', 'SpecialAttack': 65.0, 'HP': 55.0, 'Speed': 35.0, 'Attack': 55.0, 'Defense': 85.0, 'PokedexNumber': 222.0, 'SpecialDefense': 85.0, 'Total': 380.0, 'Type': 'WaterRock'}
# {'Name': 'Remoraid', 'SpecialAttack': 65.0, 'HP': 35.0, 'Speed': 65.0, 'Attack': 65.0, 'Defense': 35.0, 'PokedexNumber': 223.0, 'SpecialDefense': 35.0, 'Total': 300.0, 'Type': 'Water'}
# {'Name': 'Octillery', 'SpecialAttack': 105.0, 'HP': 75.0, 'Speed': 45.0, 'Attack': 105.0, 'Defense': 75.0, 'PokedexNumber': 224.0, 'SpecialDefense': 75.0, 'Total': 480.0, 'Type': 'Water'}
# {'Name': 'Delibird', 'SpecialAttack': 65.0, 'HP': 45.0, 'Speed': 75.0, 'Attack': 55.0, 'Defense': 45.0, 'PokedexNumber': 225.0, 'SpecialDefense': 45.0, 'Total': 330.0, 'Type': 'IceFlying'}
# {'Name': 'Mantine', 'SpecialAttack': 80.0, 'HP': 65.0, 'Speed': 70.0, 'Attack': 40.0, 'Defense': 70.0, 'PokedexNumber': 226.0, 'SpecialDefense': 140.0, 'Total': 465.0, 'Type': 'WaterFlying'}
# {'Name': 'Skarmory', 'SpecialAttack': 40.0, 'HP': 65.0, 'Speed': 70.0, 'Attack': 80.0, 'Defense': 140.0, 'PokedexNumber': 227.0, 'SpecialDefense': 70.0, 'Total': 465.0, 'Type': 'SteelFlying'}
# {'Name': 'Houndour', 'SpecialAttack': 80.0, 'HP': 45.0, 'Speed': 65.0, 'Attack': 60.0, 'Defense': 30.0, 'PokedexNumber': 228.0, 'SpecialDefense': 50.0, 'Total': 330.0, 'Type': 'DarkFire'}
# {'Name': 'Houndoom', 'SpecialAttack': 110.0, 'HP': 75.0, 'Speed': 95.0, 'Attack': 90.0, 'Defense': 50.0, 'PokedexNumber': 229.0, 'SpecialDefense': 80.0, 'Total': 500.0, 'Type': 'DarkFire'}
# {'Name': 'HoundoomMega Houndoom', 'SpecialAttack': 140.0, 'HP': 75.0, 'Speed': 115.0, 'Attack': 90.0, 'Defense': 90.0, 'PokedexNumber': 229.0, 'SpecialDefense': 90.0, 'Total': 600.0, 'Type': 'DarkFire'}
# {'Name': 'Kingdra', 'SpecialAttack': 95.0, 'HP': 75.0, 'Speed': 85.0, 'Attack': 95.0, 'Defense': 95.0, 'PokedexNumber': 230.0, 'SpecialDefense': 95.0, 'Total': 540.0, 'Type': 'WaterDragon'}
# {'Name': 'Phanpy', 'SpecialAttack': 40.0, 'HP': 90.0, 'Speed': 40.0, 'Attack': 60.0, 'Defense': 60.0, 'PokedexNumber': 231.0, 'SpecialDefense': 40.0, 'Total': 330.0, 'Type': 'Ground'}
# {'Name': 'Donphan', 'SpecialAttack': 60.0, 'HP': 90.0, 'Speed': 50.0, 'Attack': 120.0, 'Defense': 120.0, 'PokedexNumber': 232.0, 'SpecialDefense': 60.0, 'Total': 500.0, 'Type': 'Ground'}
# {'Name': 'Porygon2', 'SpecialAttack': 105.0, 'HP': 85.0, 'Speed': 60.0, 'Attack': 80.0, 'Defense': 90.0, 'PokedexNumber': 233.0, 'SpecialDefense': 95.0, 'Total': 515.0, 'Type': 'Normal'}
# ...
# {'Name': 'Chesnaught', 'SpecialAttack': 74.0, 'HP': 88.0, 'Speed': 64.0, 'Attack': 107.0, 'Defense': 122.0, 'PokedexNumber': 652.0, 'SpecialDefense': 75.0, 'Total': 530.0, 'Type': 'GrassFighting'}
# {'Name': 'Fennekin', 'SpecialAttack': 62.0, 'HP': 40.0, 'Speed': 60.0, 'Attack': 45.0, 'Defense': 40.0, 'PokedexNumber': 653.0, 'SpecialDefense': 60.0, 'Total': 307.0, 'Type': 'Fire'}
# {'Name': 'Braixen', 'SpecialAttack': 90.0, 'HP': 59.0, 'Speed': 73.0, 'Attack': 59.0, 'Defense': 58.0, 'PokedexNumber': 654.0, 'SpecialDefense': 70.0, 'Total': 409.0, 'Type': 'Fire'}
# {'Name': 'Delphox', 'SpecialAttack': 114.0, 'HP': 75.0, 'Speed': 104.0, 'Attack': 69.0, 'Defense': 72.0, 'PokedexNumber': 655.0, 'SpecialDefense': 100.0, 'Total': 534.0, 'Type': 'FirePsychic'}
# {'Name': 'Froakie', 'SpecialAttack': 62.0, 'HP': 41.0, 'Speed': 71.0, 'Attack': 56.0, 'Defense': 40.0, 'PokedexNumber': 656.0, 'SpecialDefense': 44.0, 'Total': 314.0, 'Type': 'Water'}
# {'Name': 'Frogadier', 'SpecialAttack': 83.0, 'HP': 54.0, 'Speed': 97.0, 'Attack': 63.0, 'Defense': 52.0, 'PokedexNumber': 657.0, 'SpecialDefense': 56.0, 'Total': 405.0, 'Type': 'Water'}
# {'Name': 'Greninja', 'SpecialAttack': 103.0, 'HP': 72.0, 'Speed': 122.0, 'Attack': 95.0, 'Defense': 67.0, 'PokedexNumber': 658.0, 'SpecialDefense': 71.0, 'Total': 530.0, 'Type': 'WaterDark'}
# {'Name': 'Bunnelby', 'SpecialAttack': 32.0, 'HP': 38.0, 'Speed': 57.0, 'Attack': 36.0, 'Defense': 38.0, 'PokedexNumber': 659.0, 'SpecialDefense': 36.0, 'Total': 237.0, 'Type': 'Normal'}
# {'Name': 'Diggersby', 'SpecialAttack': 50.0, 'HP': 85.0, 'Speed': 78.0, 'Attack': 56.0, 'Defense': 77.0, 'PokedexNumber': 660.0, 'SpecialDefense': 77.0, 'Total': 423.0, 'Type': 'NormalGround'}
# {'Name': 'Fletchling', 'SpecialAttack': 40.0, 'HP': 45.0, 'Speed': 62.0, 'Attack': 50.0, 'Defense': 43.0, 'PokedexNumber': 661.0, 'SpecialDefense': 38.0, 'Total': 278.0, 'Type': 'NormalFlying'}
# {'Name': 'Fletchinder', 'SpecialAttack': 56.0, 'HP': 62.0, 'Speed': 84.0, 'Attack': 73.0, 'Defense': 55.0, 'PokedexNumber': 662.0, 'SpecialDefense': 52.0, 'Total': 382.0, 'Type': 'FireFlying'}
# {'Name': 'Talonflame', 'SpecialAttack': 74.0, 'HP': 78.0, 'Speed': 126.0, 'Attack': 81.0, 'Defense': 71.0, 'PokedexNumber': 663.0, 'SpecialDefense': 69.0, 'Total': 499.0, 'Type': 'FireFlying'}
# {'Name': 'Scatterbug', 'SpecialAttack': 27.0, 'HP': 38.0, 'Speed': 35.0, 'Attack': 35.0, 'Defense': 40.0, 'PokedexNumber': 664.0, 'SpecialDefense': 25.0, 'Total': 200.0, 'Type': 'Bug'}
# {'Name': 'Spewpa', 'SpecialAttack': 27.0, 'HP': 45.0, 'Speed': 29.0, 'Attack': 22.0, 'Defense': 60.0, 'PokedexNumber': 665.0, 'SpecialDefense': 30.0, 'Total': 213.0, 'Type': 'Bug'}
# {'Name': 'Vivillon', 'SpecialAttack': 90.0, 'HP': 80.0, 'Speed': 89.0, 'Attack': 52.0, 'Defense': 50.0, 'PokedexNumber': 666.0, 'SpecialDefense': 50.0, 'Total': 411.0, 'Type': 'BugFlying'}
# {'Name': 'Litleo', 'SpecialAttack': 73.0, 'HP': 62.0, 'Speed': 72.0, 'Attack': 50.0, 'Defense': 58.0, 'PokedexNumber': 667.0, 'SpecialDefense': 54.0, 'Total': 369.0, 'Type': 'FireNormal'}
# {'Name': 'Pyroar', 'SpecialAttack': 109.0, 'HP': 86.0, 'Speed': 106.0, 'Attack': 68.0, 'Defense': 72.0, 'PokedexNumber': 668.0, 'SpecialDefense': 66.0, 'Total': 507.0, 'Type': 'FireNormal'}
# {'Name': 'Flab\xc3\xa9b\xc3\xa9', 'SpecialAttack': 61.0, 'HP': 44.0, 'Speed': 42.0, 'Attack': 38.0, 'Defense': 39.0, 'PokedexNumber': 669.0, 'SpecialDefense': 79.0, 'Total': 303.0, 'Type': 'Fairy'}
# {'Name': 'Floette', 'SpecialAttack': 75.0, 'HP': 54.0, 'Speed': 52.0, 'Attack': 45.0, 'Defense': 47.0, 'PokedexNumber': 670.0, 'SpecialDefense': 98.0, 'Total': 371.0, 'Type': 'Fairy'}
# {'Name': 'Florges', 'SpecialAttack': 112.0, 'HP': 78.0, 'Speed': 75.0, 'Attack': 65.0, 'Defense': 68.0, 'PokedexNumber': 671.0, 'SpecialDefense': 154.0, 'Total': 552.0, 'Type': 'Fairy'}
# {'Name': 'Skiddo', 'SpecialAttack': 62.0, 'HP': 66.0, 'Speed': 52.0, 'Attack': 65.0, 'Defense': 48.0, 'PokedexNumber': 672.0, 'SpecialDefense': 57.0, 'Total': 350.0, 'Type': 'Grass'}
# {'Name': 'Gogoat', 'SpecialAttack': 97.0, 'HP': 123.0, 'Speed': 68.0, 'Attack': 100.0, 'Defense': 62.0, 'PokedexNumber': 673.0, 'SpecialDefense': 81.0, 'Total': 531.0, 'Type': 'Grass'}
# {'Name': 'Pancham', 'SpecialAttack': 46.0, 'HP': 67.0, 'Speed': 43.0, 'Attack': 82.0, 'Defense': 62.0, 'PokedexNumber': 674.0, 'SpecialDefense': 48.0, 'Total': 348.0, 'Type': 'Fighting'}
# {'Name': 'Pangoro', 'SpecialAttack': 69.0, 'HP': 95.0, 'Speed': 58.0, 'Attack': 124.0, 'Defense': 78.0, 'PokedexNumber': 675.0, 'SpecialDefense': 71.0, 'Total': 495.0, 'Type': 'FightingDark'}
# {'Name': 'Furfrou', 'SpecialAttack': 65.0, 'HP': 75.0, 'Speed': 102.0, 'Attack': 80.0, 'Defense': 60.0, 'PokedexNumber': 676.0, 'SpecialDefense': 90.0, 'Total': 472.0, 'Type': 'Normal'}
# {'Name': 'Espurr', 'SpecialAttack': 63.0, 'HP': 62.0, 'Speed': 68.0, 'Attack': 48.0, 'Defense': 54.0, 'PokedexNumber': 677.0, 'SpecialDefense': 60.0, 'Total': 355.0, 'Type': 'Psychic'}
# {'Name': 'MeowsticMale', 'SpecialAttack': 83.0, 'HP': 74.0, 'Speed': 104.0, 'Attack': 48.0, 'Defense': 76.0, 'PokedexNumber': 678.0, 'SpecialDefense': 81.0, 'Total': 466.0, 'Type': 'Psychic'}
# {'Name': 'MeowsticFemale', 'SpecialAttack': 83.0, 'HP': 74.0, 'Speed': 104.0, 'Attack': 48.0, 'Defense': 76.0, 'PokedexNumber': 678.0, 'SpecialDefense': 81.0, 'Total': 466.0, 'Type': 'Psychic'}
# {'Name': 'Honedge', 'SpecialAttack': 35.0, 'HP': 45.0, 'Speed': 28.0, 'Attack': 80.0, 'Defense': 100.0, 'PokedexNumber': 679.0, 'SpecialDefense': 37.0, 'Total': 325.0, 'Type': 'SteelGhost'}
# {'Name': 'Doublade', 'SpecialAttack': 45.0, 'HP': 59.0, 'Speed': 35.0, 'Attack': 110.0, 'Defense': 150.0, 'PokedexNumber': 680.0, 'SpecialDefense': 49.0, 'Total': 448.0, 'Type': 'SteelGhost'}
# {'Name': 'AegislashBlade Forme', 'SpecialAttack': 150.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 150.0, 'Defense': 50.0, 'PokedexNumber': 681.0, 'SpecialDefense': 50.0, 'Total': 520.0, 'Type': 'SteelGhost'}
# {'Name': 'AegislashShield Forme', 'SpecialAttack': 50.0, 'HP': 60.0, 'Speed': 60.0, 'Attack': 50.0, 'Defense': 150.0, 'PokedexNumber': 681.0, 'SpecialDefense': 150.0, 'Total': 520.0, 'Type': 'SteelGhost'}
# {'Name': 'Spritzee', 'SpecialAttack': 63.0, 'HP': 78.0, 'Speed': 23.0, 'Attack': 52.0, 'Defense': 60.0, 'PokedexNumber': 682.0, 'SpecialDefense': 65.0, 'Total': 341.0, 'Type': 'Fairy'}
# {'Name': 'Aromatisse', 'SpecialAttack': 99.0, 'HP': 101.0, 'Speed': 29.0, 'Attack': 72.0, 'Defense': 72.0, 'PokedexNumber': 683.0, 'SpecialDefense': 89.0, 'Total': 462.0, 'Type': 'Fairy'}
# {'Name': 'Swirlix', 'SpecialAttack': 59.0, 'HP': 62.0, 'Speed': 49.0, 'Attack': 48.0, 'Defense': 66.0, 'PokedexNumber': 684.0, 'SpecialDefense': 57.0, 'Total': 341.0, 'Type': 'Fairy'}
# {'Name': 'Slurpuff', 'SpecialAttack': 85.0, 'HP': 82.0, 'Speed': 72.0, 'Attack': 80.0, 'Defense': 86.0, 'PokedexNumber': 685.0, 'SpecialDefense': 75.0, 'Total': 480.0, 'Type': 'Fairy'}
# {'Name': 'Inkay', 'SpecialAttack': 37.0, 'HP': 53.0, 'Speed': 45.0, 'Attack': 54.0, 'Defense': 53.0, 'PokedexNumber': 686.0, 'SpecialDefense': 46.0, 'Total': 288.0, 'Type': 'DarkPsychic'}
# {'Name': 'Malamar', 'SpecialAttack': 68.0, 'HP': 86.0, 'Speed': 73.0, 'Attack': 92.0, 'Defense': 88.0, 'PokedexNumber': 687.0, 'SpecialDefense': 75.0, 'Total': 482.0, 'Type': 'DarkPsychic'}
# {'Name': 'Binacle', 'SpecialAttack': 39.0, 'HP': 42.0, 'Speed': 50.0, 'Attack': 52.0, 'Defense': 67.0, 'PokedexNumber': 688.0, 'SpecialDefense': 56.0, 'Total': 306.0, 'Type': 'RockWater'}
# {'Name': 'Barbaracle', 'SpecialAttack': 54.0, 'HP': 72.0, 'Speed': 68.0, 'Attack': 105.0, 'Defense': 115.0, 'PokedexNumber': 689.0, 'SpecialDefense': 86.0, 'Total': 500.0, 'Type': 'RockWater'}
# {'Name': 'Skrelp', 'SpecialAttack': 60.0, 'HP': 50.0, 'Speed': 30.0, 'Attack': 60.0, 'Defense': 60.0, 'PokedexNumber': 690.0, 'SpecialDefense': 60.0, 'Total': 320.0, 'Type': 'PoisonWater'}
# {'Name': 'Dragalge', 'SpecialAttack': 97.0, 'HP': 65.0, 'Speed': 44.0, 'Attack': 75.0, 'Defense': 90.0, 'PokedexNumber': 691.0, 'SpecialDefense': 123.0, 'Total': 494.0, 'Type': 'PoisonDragon'}
# {'Name': 'Clauncher', 'SpecialAttack': 58.0, 'HP': 50.0, 'Speed': 44.0, 'Attack': 53.0, 'Defense': 62.0, 'PokedexNumber': 692.0, 'SpecialDefense': 63.0, 'Total': 330.0, 'Type': 'Water'}
# {'Name': 'Clawitzer', 'SpecialAttack': 120.0, 'HP': 71.0, 'Speed': 59.0, 'Attack': 73.0, 'Defense': 88.0, 'PokedexNumber': 693.0, 'SpecialDefense': 89.0, 'Total': 500.0, 'Type': 'Water'}
# {'Name': 'Helioptile', 'SpecialAttack': 61.0, 'HP': 44.0, 'Speed': 70.0, 'Attack': 38.0, 'Defense': 33.0, 'PokedexNumber': 694.0, 'SpecialDefense': 43.0, 'Total': 289.0, 'Type': 'ElectricNormal'}
# {'Name': 'Heliolisk', 'SpecialAttack': 109.0, 'HP': 62.0, 'Speed': 109.0, 'Attack': 55.0, 'Defense': 52.0, 'PokedexNumber': 695.0, 'SpecialDefense': 94.0, 'Total': 481.0, 'Type': 'ElectricNormal'}
# {'Name': 'Tyrunt', 'SpecialAttack': 45.0, 'HP': 58.0, 'Speed': 48.0, 'Attack': 89.0, 'Defense': 77.0, 'PokedexNumber': 696.0, 'SpecialDefense': 45.0, 'Total': 362.0, 'Type': 'RockDragon'}
# {'Name': 'Tyrantrum', 'SpecialAttack': 69.0, 'HP': 82.0, 'Speed': 71.0, 'Attack': 121.0, 'Defense': 119.0, 'PokedexNumber': 697.0, 'SpecialDefense': 59.0, 'Total': 521.0, 'Type': 'RockDragon'}
# {'Name': 'Amaura', 'SpecialAttack': 67.0, 'HP': 77.0, 'Speed': 46.0, 'Attack': 59.0, 'Defense': 50.0, 'PokedexNumber': 698.0, 'SpecialDefense': 63.0, 'Total': 362.0, 'Type': 'RockIce'}
# {'Name': 'Aurorus', 'SpecialAttack': 99.0, 'HP': 123.0, 'Speed': 58.0, 'Attack': 77.0, 'Defense': 72.0, 'PokedexNumber': 699.0, 'SpecialDefense': 92.0, 'Total': 521.0, 'Type': 'RockIce'}
# {'Name': 'Sylveon', 'SpecialAttack': 110.0, 'HP': 95.0, 'Speed': 60.0, 'Attack': 65.0, 'Defense': 65.0, 'PokedexNumber': 700.0, 'SpecialDefense': 130.0, 'Total': 525.0, 'Type': 'Fairy'}
# {'Name': 'Hawlucha', 'SpecialAttack': 74.0, 'HP': 78.0, 'Speed': 118.0, 'Attack': 92.0, 'Defense': 75.0, 'PokedexNumber': 701.0, 'SpecialDefense': 63.0, 'Total': 500.0, 'Type': 'FightingFlying'}
# {'Name': 'Dedenne', 'SpecialAttack': 81.0, 'HP': 67.0, 'Speed': 101.0, 'Attack': 58.0, 'Defense': 57.0, 'PokedexNumber': 702.0, 'SpecialDefense': 67.0, 'Total': 431.0, 'Type': 'ElectricFairy'}
# {'Name': 'Carbink', 'SpecialAttack': 50.0, 'HP': 50.0, 'Speed': 50.0, 'Attack': 50.0, 'Defense': 150.0, 'PokedexNumber': 703.0, 'SpecialDefense': 150.0, 'Total': 500.0, 'Type': 'RockFairy'}
# {'Name': 'Goomy', 'SpecialAttack': 55.0, 'HP': 45.0, 'Speed': 40.0, 'Attack': 50.0, 'Defense': 35.0, 'PokedexNumber': 704.0, 'SpecialDefense': 75.0, 'Total': 300.0, 'Type': 'Dragon'}
# {'Name': 'Sliggoo', 'SpecialAttack': 83.0, 'HP': 68.0, 'Speed': 60.0, 'Attack': 75.0, 'Defense': 53.0, 'PokedexNumber': 705.0, 'SpecialDefense': 113.0, 'Total': 452.0, 'Type': 'Dragon'}
# {'Name': 'Goodra', 'SpecialAttack': 110.0, 'HP': 90.0, 'Speed': 80.0, 'Attack': 100.0, 'Defense': 70.0, 'PokedexNumber': 706.0, 'SpecialDefense': 150.0, 'Total': 600.0, 'Type': 'Dragon'}
# {'Name': 'Klefki', 'SpecialAttack': 80.0, 'HP': 57.0, 'Speed': 75.0, 'Attack': 80.0, 'Defense': 91.0, 'PokedexNumber': 707.0, 'SpecialDefense': 87.0, 'Total': 470.0, 'Type': 'SteelFairy'}
# {'Name': 'Phantump', 'SpecialAttack': 50.0, 'HP': 43.0, 'Speed': 38.0, 'Attack': 70.0, 'Defense': 48.0, 'PokedexNumber': 708.0, 'SpecialDefense': 60.0, 'Total': 309.0, 'Type': 'GhostGrass'}
# {'Name': 'Trevenant', 'SpecialAttack': 65.0, 'HP': 85.0, 'Speed': 56.0, 'Attack': 110.0, 'Defense': 76.0, 'PokedexNumber': 709.0, 'SpecialDefense': 82.0, 'Total': 474.0, 'Type': 'GhostGrass'}
# {'Name': 'PumpkabooAverage Size', 'SpecialAttack': 44.0, 'HP': 49.0, 'Speed': 51.0, 'Attack': 66.0, 'Defense': 70.0, 'PokedexNumber': 710.0, 'SpecialDefense': 55.0, 'Total': 335.0, 'Type': 'GhostGrass'}
# {'Name': 'PumpkabooSmall Size', 'SpecialAttack': 44.0, 'HP': 44.0, 'Speed': 56.0, 'Attack': 66.0, 'Defense': 70.0, 'PokedexNumber': 710.0, 'SpecialDefense': 55.0, 'Total': 335.0, 'Type': 'GhostGrass'}
# {'Name': 'PumpkabooLarge Size', 'SpecialAttack': 44.0, 'HP': 54.0, 'Speed': 46.0, 'Attack': 66.0, 'Defense': 70.0, 'PokedexNumber': 710.0, 'SpecialDefense': 55.0, 'Total': 335.0, 'Type': 'GhostGrass'}
# {'Name': 'PumpkabooSuper Size', 'SpecialAttack': 44.0, 'HP': 59.0, 'Speed': 41.0, 'Attack': 66.0, 'Defense': 70.0, 'PokedexNumber': 710.0, 'SpecialDefense': 55.0, 'Total': 335.0, 'Type': 'GhostGrass'}
# {'Name': 'GourgeistAverage Size', 'SpecialAttack': 58.0, 'HP': 65.0, 'Speed': 84.0, 'Attack': 90.0, 'Defense': 122.0, 'PokedexNumber': 711.0, 'SpecialDefense': 75.0, 'Total': 494.0, 'Type': 'GhostGrass'}
# {'Name': 'GourgeistSmall Size', 'SpecialAttack': 58.0, 'HP': 55.0, 'Speed': 99.0, 'Attack': 85.0, 'Defense': 122.0, 'PokedexNumber': 711.0, 'SpecialDefense': 75.0, 'Total': 494.0, 'Type': 'GhostGrass'}
# {'Name': 'GourgeistLarge Size', 'SpecialAttack': 58.0, 'HP': 75.0, 'Speed': 69.0, 'Attack': 95.0, 'Defense': 122.0, 'PokedexNumber': 711.0, 'SpecialDefense': 75.0, 'Total': 494.0, 'Type': 'GhostGrass'}
# {'Name': 'GourgeistSuper Size', 'SpecialAttack': 58.0, 'HP': 85.0, 'Speed': 54.0, 'Attack': 100.0, 'Defense': 122.0, 'PokedexNumber': 711.0, 'SpecialDefense': 75.0, 'Total': 494.0, 'Type': 'GhostGrass'}
# {'Name': 'Bergmite', 'SpecialAttack': 32.0, 'HP': 55.0, 'Speed': 28.0, 'Attack': 69.0, 'Defense': 85.0, 'PokedexNumber': 712.0, 'SpecialDefense': 35.0, 'Total': 304.0, 'Type': 'Ice'}
# {'Name': 'Avalugg', 'SpecialAttack': 44.0, 'HP': 95.0, 'Speed': 28.0, 'Attack': 117.0, 'Defense': 184.0, 'PokedexNumber': 713.0, 'SpecialDefense': 46.0, 'Total': 514.0, 'Type': 'Ice'}
# {'Name': 'Noibat', 'SpecialAttack': 45.0, 'HP': 40.0, 'Speed': 55.0, 'Attack': 30.0, 'Defense': 35.0, 'PokedexNumber': 714.0, 'SpecialDefense': 40.0, 'Total': 245.0, 'Type': 'FlyingDragon'}
# {'Name': 'Noivern', 'SpecialAttack': 97.0, 'HP': 85.0, 'Speed': 123.0, 'Attack': 70.0, 'Defense': 80.0, 'PokedexNumber': 715.0, 'SpecialDefense': 80.0, 'Total': 535.0, 'Type': 'FlyingDragon'}
# {'Name': 'Xerneas', 'SpecialAttack': 131.0, 'HP': 126.0, 'Speed': 99.0, 'Attack': 131.0, 'Defense': 95.0, 'PokedexNumber': 716.0, 'SpecialDefense': 98.0, 'Total': 680.0, 'Type': 'Fairy'}
# {'Name': 'Yveltal', 'SpecialAttack': 131.0, 'HP': 126.0, 'Speed': 99.0, 'Attack': 131.0, 'Defense': 95.0, 'PokedexNumber': 717.0, 'SpecialDefense': 98.0, 'Total': 680.0, 'Type': 'DarkFlying'}
# {'Name': 'Zygarde50% Forme', 'SpecialAttack': 81.0, 'HP': 108.0, 'Speed': 95.0, 'Attack': 100.0, 'Defense': 121.0, 'PokedexNumber': 718.0, 'SpecialDefense': 95.0, 'Total': 600.0, 'Type': 'DragonGround'}
# {'Name': 'Diancie', 'SpecialAttack': 100.0, 'HP': 50.0, 'Speed': 50.0, 'Attack': 100.0, 'Defense': 150.0, 'PokedexNumber': 719.0, 'SpecialDefense': 150.0, 'Total': 600.0, 'Type': 'RockFairy'}
# {'Name': 'DiancieMega Diancie', 'SpecialAttack': 160.0, 'HP': 50.0, 'Speed': 110.0, 'Attack': 160.0, 'Defense': 110.0, 'PokedexNumber': 719.0, 'SpecialDefense': 110.0, 'Total': 700.0, 'Type': 'RockFairy'}
# {'Name': 'HoopaHoopa Confined', 'SpecialAttack': 150.0, 'HP': 80.0, 'Speed': 70.0, 'Attack': 110.0, 'Defense': 60.0, 'PokedexNumber': 720.0, 'SpecialDefense': 130.0, 'Total': 600.0, 'Type': 'PsychicGhost'}
# {'Name': 'HoopaHoopa Unbound', 'SpecialAttack': 170.0, 'HP': 80.0, 'Speed': 80.0, 'Attack': 160.0, 'Defense': 60.0, 'PokedexNumber': 720.0, 'SpecialDefense': 130.0, 'Total': 680.0, 'Type': 'PsychicDark'}
# {'Name': 'Volcanion', 'SpecialAttack': 130.0, 'HP': 80.0, 'Speed': 70.0, 'Attack': 110.0, 'Defense': 120.0, 'PokedexNumber': 721.0, 'SpecialDefense': 90.0, 'Total': 600.0, 'Type': 'FireWater'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-f6b9f0da6844> in <module>()
#       5 }
#       6
# ----> 7 filtered_pokedex(lc_dex,filter_options)
#
# <ipython-input-80-8ef8fb25c5af> in filtered_pokedex(pokedex_data, filter_options)
#       3     output =[]
#       4     for key in filter_options.keys():
# ----> 5         for value in filter_options.values:
#       6             for pokemon in data:
#       7                 if type(value) == "Float":
#
# TypeError: 'builtin_function_or_method' object is not iterable
