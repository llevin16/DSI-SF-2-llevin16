# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
#
# After reading the gushing praise for Pokemon Go you decide to download it and try it out for yourself. Yet a couple hours of play later you find yourself disappointed by the fact that you _actually_ have to move around outside.
#
# Though just a beginner programmer, you decide to make your own iteration on the genre: "Pokemon Stay". In this version players still need to move, but just from website to website. Pokemon gyms are now popular cyber-destinations, and catching pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# ---
#
# #### Package imports
#
# The `pprint` package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create a player. The dictionary and list variables should just be defined as empty at this point.

# %%
my_player = {"player_id":16, "player_name":"Lenny", "time_played":576.4, "player_pokemon":{}, "gyms_visited":[]}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
# Example output:
# 
# ['amazon.com', 'ebay.com']
gyms = ["reddit.com","amazon.com","twitter.com","linkedin.com","ebay.com","netflix.com","amazon.com","stackoverflow.com",
       "github.com","quora.com"]
#appends twice to keep from adding a list of gyms instead of the strings themselves
my_player["gyms_visited"].append(gyms[1])
my_player["gyms_visited"].append(gyms[2])
print my_player["gyms_visited"]
# Out:
# ['amazon.com', 'twitter.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print the pokedex dictionary with the 3 pokemon.

# %%
# No example output... too similar to the answer!
pokemon = {
    1: {
        "name":"charmander","type":"fire","hp":20,"attack":20,"defense":20,"special_attack":20,"special_defense":20,
        "speed":20
    },
    2: {
        "name":"squirtle","type":"water","hp":15,"attack":15,"defense":15,"special_attack":15,"special_defense":15,
        "speed":15
    },
    3: {
        "name":"bulbasaur","type":"poison","hp":10,"attack":10,"defense":10,"special_attack":10,"special_defense":10,
        "speed":10
    }
}

print pokemon
# Out:
# {1: {'attack': 20, 'defense': 20, 'name': 'charmander', 'special_attack': 20, 'speed': 20, 'hp': 20, 'type': 'fire', 'special_defense': 20}, 2: {'attack': 15, 'defense': 15, 'name': 'squirtle', 'special_attack': 15, 'speed': 15, 'hp': 15, 'type': 'water', 'special_defense': 15}, 3: {'attack': 10, 'defense': 10, 'name': 'bulbasaur', 'special_attack': 10, 'speed': 10, 'hp': 10, 'type': 'poison', 'special_defense': 10}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1). **The values in the player's dictionary will be the variables you assigned in question 1.**
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {},
#      'time_played': 0.0}}
players_dict = {}
players_dict[my_player["player_id"]] = my_player
print players_dict
# Out:
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {}}}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'stackoverflow.com'` and `'github.com'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
# No example output. 
new_player = {"player_id":2,"player_name":"Homie","time_played":15.,"gyms_visited":[],"player_pokemon":{}}
new_player["gyms_visited"].append("quora.com")
new_player["gyms_visited"].append("ebay.com")
players_dict[new_player["player_id"]] = new_player
print new_player
print players_dict
# Out:
# {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {}}
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {}}, 2: {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
# Example output from print:
#
# {1: {'gyms_visited': ['amazon.com', 'ebay.com'],
#      'player_name': 'Ash',
#      'player_pokemon': {2: ...squirtle dictionary...},
#      'time_played': 0.0},
#  2: {'gyms_visited': ['stackoverflow.com', 'github.com'],
#      'player_name': 'Brock',
#      'player_pokemon': {1: ...charmander dictionary..., 3: ...bulbasaur dictionary...},
#      'time_played': 10.0}}
players_dict[16]["player_pokemon"]={2:pokemon[2]}
players_dict[2]["player_pokemon"]={1:pokemon[1],3:pokemon[3]}
print players_dict
# Out:
# {16: {'player_id': 16, 'time_played': 576.4, 'gyms_visited': ['amazon.com', 'twitter.com'], 'player_name': 'Lenny', 'player_pokemon': {2: {'attack': 15, 'defense': 15, 'name': 'squirtle', 'special_attack': 15, 'speed': 15, 'hp': 15, 'type': 'water', 'special_defense': 15}}}, 2: {'player_id': 2, 'time_played': 15.0, 'gyms_visited': ['quora.com', 'ebay.com'], 'player_name': 'Homie', 'player_pokemon': {1: {'attack': 20, 'defense': 20, 'name': 'charmander', 'special_attack': 20, 'speed': 20, 'hp': 20, 'type': 'fire', 'special_defense': 20}, 3: {'attack': 10, 'defense': 10, 'name': 'bulbasaur', 'special_attack': 10, 'speed': 10, 'hp': 10, 'type': 'poison', 'special_defense': 10}}}}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. What gyms have players visited?
#
# ---
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
# Example output:
#
# Ash has visited amazon.com.
# Ash has visited ebay.com.
# Ash has visited amazon.com.
# Brock has visited stackoverflow.com.
# Brock has visited github.com.
for gym in gyms:
    for player in players_dict:
        if gym in players_dict[player]["gyms_visited"]:
            print "%s has visited %s" %(players_dict[player]["player_name"],gym)
# Out:
# Lenny has visited amazon.com
# Lenny has visited twitter.com
# Homie has visited ebay.com
# Lenny has visited amazon.com
# Homie has visited quora.com

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
# Example output:
#
# Ash's power is 57.
# 57
# Brock's power is 119.
# 119
def power (player_dict,pokedex,player_id):
    pokemon_list = player_dict[player_id]["player_pokemon"]
    power = 0
    for pokemon in pokedex: #goes through all pokemon ids
        if pokemon in pokemon_list.keys(): #if the id is in the players pokemon ids, adds that power to the cumulative
            power += pokedex[pokemon]["attack"] + pokedex[pokemon]["defense"] + pokedex[pokemon]["special_attack"] \
            + pokedex[pokemon]["special_defense"]
    print "%s's power is %s" %(player_dict[player_id]["player_name"],str(power))
    return power

print power(players_dict,pokemon,16)
print power(players_dict,pokemon,2)
# Out:
# Lenny's power is 60
# 60
# Homie's power is 120
# 120

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# Now we have access to the raw base stats on all of the pokemon, scraped from the web.
#
# The provided code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# The first three lists in your pokedex list should look like so:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
raw_pd = ''
pokedex_file = 'pokedex_basic.csv'
with open(pokedex_file, 'r') as f:
    raw_pd = f.read()
    
# the pokedex string is assigned to the raw_pd variable

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
output_dex = []
for item in raw_pd.split("\n"): #splits the string into lines
    item = item.replace('"',"") #removes the quotes
    new_line = []
    for line in item.split(","):#splits the lines into strings
        #tries to convert the strings into floats. If not possible, sees if it's blank or not
        try:
            line = float(line) 
        except:
            if line == "":
                line = -1
        new_line.append(line)
    output_dex.append(new_line)

# %% [markdown]
# <img src="http://imgur.com/gGrau8s.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %%
# Example output (first 3 sublists):
#
# ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
# [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
# [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]
#puts the type conversion into a function which i then call within the comprehension.
def try_catch(x):
    try: 
        return float(x)
    except:
        if x == "":
            return -1
        else:
            return x

#first splits the data into lines, then splits each line again to get the string values, and then both converts and 
#removes the quotes (conversion via the function)
lc_dex = [[try_catch(line.replace('"',"")) for line in item.split(",")] for item in raw_pd.split("\n")]
lc_dex[:2]
# Out:
# [['PokedexNumber',
#   'Name',
#   'Type',
#   'Total',
#   'HP',
#   'Attack',
#   'Defense',
#   'SpecialAttack',
#   'SpecialDefense',
#   'Speed'],
#  [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]]

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
# Example output:
#
# {'Attack': 30.0,
#  'Defense': 50.0,
#  'HP': 40.0,
#  'Name': 'Voltorb',
#  'SpecialAttack': 55.0,
#  'SpecialDefense': 55.0,
#  'Speed': 100.0,
#  'Total': 330.0,
#  'Type': 'Electric'}
def gen_pokedex(pokedex):
    output = {} 
    header = pokedex[0]
    data = pokedex[1:]
    # goes through the pokedex, initializes a blank dictionary and adds each pokemon dictionary to it. Then goes back 
    # and adds those dictionaries as values to the pokemon id key in the final output dictionary.
    for row in data[:-1]:
        pokemon_dict = {}
        for index, item in enumerate(header):
            pokemon_dict[item] = row[index]
        output[row[0]] = pokemon_dict
    return output

        
#gen_pokedex(lc_dex)

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def filtered_pokedex(pokedex_data, filter_options):
    data = gen_pokedex(pokedex_data)
    output =[]
    temp = []
    for pokemon in data:
        for criteria in filter_options:
            try:
                if type(filter_options[criteria]).__name__ == "str" and data[pokemon][criteria] == filter_options[criteria]:
                    temp.append(pokemon)
            except:
                pass
    for pokemon in temp:
        for criteria in filter_options:
            try:
                if (type(filter_options[criteria]).__name__ == "int" or type(filter_options[criteria]).__name__ == "float") and data[pokemon][criteria] >= filter_options[criteria]:
                    output.append(data[pokemon])
            except:
                pass
    return output

# I know this technically doesn't do the request since if there are multiple of one type of criteria (multiple strings, etc.)
# it won't split those up and will turn into and include pokemon which have either of the multiple conditions met. 
# I was thinking I would put the whole thing into a for loop to go through every criteria? or maybe a while loop and remove
# a criteria every time sommehow but ran out of time. Also wasn't sure how the "filter=" part worked in the question.

# %%
filter_options = {
    'Attack':   25,
    'Defense':  30,
    'Type':     'Electric'
}

filtered_pokedex(lc_dex,filter_options)
# Out:
# [{'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Pikachu',
#   'PokedexNumber': 25.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 320.0,
#   'Type': 'Electric'},
#  {'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Pikachu',
#   'PokedexNumber': 25.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 50.0,
#   'Speed': 90.0,
#   'Total': 320.0,
#   'Type': 'Electric'},
#  {'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'PokedexNumber': 26.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  {'Attack': 90.0,
#   'Defense': 55.0,
#   'HP': 60.0,
#   'Name': 'Raichu',
#   'PokedexNumber': 26.0,
#   'SpecialAttack': 90.0,
#   'SpecialDefense': 80.0,
#   'Speed': 110.0,
#   'Total': 485.0,
#   'Type': 'Electric'},
#  {'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'},
#  {'Attack': 30.0,
#   'Defense': 50.0,
#   'HP': 40.0,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100.0,
#   'SpecialAttack': 55.0,
#   'SpecialDefense': 55.0,
#   'Speed': 100.0,
#   'Total': 330.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'PokedexNumber': 101.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Electrode',
#   'PokedexNumber': 101.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 80.0,
#   'Speed': 140.0,
#   'Total': 480.0,
#   'Type': 'Electric'},
#  {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'PokedexNumber': 125.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
#   'Type': 'Electric'},
#  {'Attack': 83.0,
#   'Defense': 57.0,
#   'HP': 65.0,
#   'Name': 'Electabuzz',
#   'PokedexNumber': 125.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 105.0,
#   'Total': 490.0,
#   'Type': 'Electric'},
#  {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Jolteon',
#   'PokedexNumber': 135.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 525.0,
#   'Type': 'Electric'},
#  {'Attack': 65.0,
#   'Defense': 60.0,
#   'HP': 65.0,
#   'Name': 'Jolteon',
#   'PokedexNumber': 135.0,
#   'SpecialAttack': 110.0,
#   'SpecialDefense': 95.0,
#   'Speed': 130.0,
#   'Total': 525.0,
#   'Type': 'Electric'},
#  {'Attack': 40.0,
#   'Defense': 15.0,
#   'HP': 20.0,
#   'Name': 'Pichu',
#   'PokedexNumber': 172.0,
#   'SpecialAttack': 35.0,
#   'SpecialDefense': 35.0,
#   'Speed': 60.0,
#   'Total': 205.0,
#   'Type': 'Electric'},
#  {'Attack': 40.0,
#   'Defense': 40.0,
#   'HP': 55.0,
#   'Name': 'Mareep',
#   'PokedexNumber': 179.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 280.0,
#   'Type': 'Electric'},
#  {'Attack': 40.0,
#   'Defense': 40.0,
#   'HP': 55.0,
#   'Name': 'Mareep',
#   'PokedexNumber': 179.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 45.0,
#   'Speed': 35.0,
#   'Total': 280.0,
#   'Type': 'Electric'},
#  {'Attack': 55.0,
#   'Defense': 55.0,
#   'HP': 70.0,
#   'Name': 'Flaaffy',
#   'PokedexNumber': 180.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 365.0,
#   'Type': 'Electric'},
#  {'Attack': 55.0,
#   'Defense': 55.0,
#   'HP': 70.0,
#   'Name': 'Flaaffy',
#   'PokedexNumber': 180.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 60.0,
#   'Speed': 45.0,
#   'Total': 365.0,
#   'Type': 'Electric'},
#  {'Attack': 63.0,
#   'Defense': 37.0,
#   'HP': 45.0,
#   'Name': 'Elekid',
#   'PokedexNumber': 239.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 55.0,
#   'Speed': 95.0,
#   'Total': 360.0,
#   'Type': 'Electric'},
#  {'Attack': 63.0,
#   'Defense': 37.0,
#   'HP': 45.0,
#   'Name': 'Elekid',
#   'PokedexNumber': 239.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 55.0,
#   'Speed': 95.0,
#   'Total': 360.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Raikou',
#   'PokedexNumber': 243.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 100.0,
#   'Speed': 115.0,
#   'Total': 580.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 75.0,
#   'HP': 90.0,
#   'Name': 'Raikou',
#   'PokedexNumber': 243.0,
#   'SpecialAttack': 115.0,
#   'SpecialDefense': 100.0,
#   'Speed': 115.0,
#   'Total': 580.0,
#   'Type': 'Electric'},
#  {'Attack': 45.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Electrike',
#   'PokedexNumber': 309.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 40.0,
#   'Speed': 65.0,
#   'Total': 295.0,
#   'Type': 'Electric'},
#  {'Attack': 45.0,
#   'Defense': 40.0,
#   'HP': 40.0,
#   'Name': 'Electrike',
#   'PokedexNumber': 309.0,
#   'SpecialAttack': 65.0,
#   'SpecialDefense': 40.0,
#   'Speed': 65.0,
#   'Total': 295.0,
#   'Type': 'Electric'},
#  {'Attack': 75.0,
#   'Defense': 80.0,
#   'HP': 70.0,
#   'Name': 'ManectricMega Manectric',
#   'PokedexNumber': 310.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed': 135.0,
#   'Total': 575.0,
#   'Type': 'Electric'},
#  {'Attack': 75.0,
#   'Defense': 80.0,
#   'HP': 70.0,
#   'Name': 'ManectricMega Manectric',
#   'PokedexNumber': 310.0,
#   'SpecialAttack': 135.0,
#   'SpecialDefense': 80.0,
#   'Speed': 135.0,
#   'Total': 575.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 40.0,
#   'HP': 60.0,
#   'Name': 'Plusle',
#   'PokedexNumber': 311.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 50.0,
#   'Defense': 40.0,
#   'HP': 60.0,
#   'Name': 'Plusle',
#   'PokedexNumber': 311.0,
#   'SpecialAttack': 85.0,
#   'SpecialDefense': 75.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 40.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Minun',
#   'PokedexNumber': 312.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 85.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 40.0,
#   'Defense': 50.0,
#   'HP': 60.0,
#   'Name': 'Minun',
#   'PokedexNumber': 312.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 85.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 65.0,
#   'Defense': 34.0,
#   'HP': 45.0,
#   'Name': 'Shinx',
#   'PokedexNumber': 403.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 34.0,
#   'Speed': 45.0,
#   'Total': 263.0,
#   'Type': 'Electric'},
#  {'Attack': 65.0,
#   'Defense': 34.0,
#   'HP': 45.0,
#   'Name': 'Shinx',
#   'PokedexNumber': 403.0,
#   'SpecialAttack': 40.0,
#   'SpecialDefense': 34.0,
#   'Speed': 45.0,
#   'Total': 263.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 49.0,
#   'HP': 60.0,
#   'Name': 'Luxio',
#   'PokedexNumber': 404.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 49.0,
#   'Speed': 60.0,
#   'Total': 363.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 49.0,
#   'HP': 60.0,
#   'Name': 'Luxio',
#   'PokedexNumber': 404.0,
#   'SpecialAttack': 60.0,
#   'SpecialDefense': 49.0,
#   'Speed': 60.0,
#   'Total': 363.0,
#   'Type': 'Electric'},
#  {'Attack': 120.0,
#   'Defense': 79.0,
#   'HP': 80.0,
#   'Name': 'Luxray',
#   'PokedexNumber': 405.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 79.0,
#   'Speed': 70.0,
#   'Total': 523.0,
#   'Type': 'Electric'},
#  {'Attack': 120.0,
#   'Defense': 79.0,
#   'HP': 80.0,
#   'Name': 'Luxray',
#   'PokedexNumber': 405.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 79.0,
#   'Speed': 70.0,
#   'Total': 523.0,
#   'Type': 'Electric'},
#  {'Attack': 45.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Pachirisu',
#   'PokedexNumber': 417.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 90.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 45.0,
#   'Defense': 70.0,
#   'HP': 60.0,
#   'Name': 'Pachirisu',
#   'PokedexNumber': 417.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 90.0,
#   'Speed': 95.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 123.0,
#   'Defense': 67.0,
#   'HP': 75.0,
#   'Name': 'Electivire',
#   'PokedexNumber': 466.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 95.0,
#   'Total': 540.0,
#   'Type': 'Electric'},
#  {'Attack': 123.0,
#   'Defense': 67.0,
#   'HP': 75.0,
#   'Name': 'Electivire',
#   'PokedexNumber': 466.0,
#   'SpecialAttack': 95.0,
#   'SpecialDefense': 85.0,
#   'Speed': 95.0,
#   'Total': 540.0,
#   'Type': 'Electric'},
#  {'Attack': 60.0,
#   'Defense': 32.0,
#   'HP': 45.0,
#   'Name': 'Blitzle',
#   'PokedexNumber': 522.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 32.0,
#   'Speed': 76.0,
#   'Total': 295.0,
#   'Type': 'Electric'},
#  {'Attack': 60.0,
#   'Defense': 32.0,
#   'HP': 45.0,
#   'Name': 'Blitzle',
#   'PokedexNumber': 522.0,
#   'SpecialAttack': 50.0,
#   'SpecialDefense': 32.0,
#   'Speed': 76.0,
#   'Total': 295.0,
#   'Type': 'Electric'},
#  {'Attack': 100.0,
#   'Defense': 63.0,
#   'HP': 75.0,
#   'Name': 'Zebstrika',
#   'PokedexNumber': 523.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 63.0,
#   'Speed': 116.0,
#   'Total': 497.0,
#   'Type': 'Electric'},
#  {'Attack': 100.0,
#   'Defense': 63.0,
#   'HP': 75.0,
#   'Name': 'Zebstrika',
#   'PokedexNumber': 523.0,
#   'SpecialAttack': 80.0,
#   'SpecialDefense': 63.0,
#   'Speed': 116.0,
#   'Total': 497.0,
#   'Type': 'Electric'},
#  {'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Tynamo',
#   'PokedexNumber': 602.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 40.0,
#   'Speed': 60.0,
#   'Total': 275.0,
#   'Type': 'Electric'},
#  {'Attack': 55.0,
#   'Defense': 40.0,
#   'HP': 35.0,
#   'Name': 'Tynamo',
#   'PokedexNumber': 602.0,
#   'SpecialAttack': 45.0,
#   'SpecialDefense': 40.0,
#   'Speed': 60.0,
#   'Total': 275.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Eelektrik',
#   'PokedexNumber': 603.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 70.0,
#   'Speed': 40.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 85.0,
#   'Defense': 70.0,
#   'HP': 65.0,
#   'Name': 'Eelektrik',
#   'PokedexNumber': 603.0,
#   'SpecialAttack': 75.0,
#   'SpecialDefense': 70.0,
#   'Speed': 40.0,
#   'Total': 405.0,
#   'Type': 'Electric'},
#  {'Attack': 115.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Eelektross',
#   'PokedexNumber': 604.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 80.0,
#   'Speed': 50.0,
#   'Total': 515.0,
#   'Type': 'Electric'},
#  {'Attack': 115.0,
#   'Defense': 80.0,
#   'HP': 85.0,
#   'Name': 'Eelektross',
#   'PokedexNumber': 604.0,
#   'SpecialAttack': 105.0,
#   'SpecialDefense': 80.0,
#   'Speed': 50.0,
#   'Total': 515.0,
#   'Type': 'Electric'}]
